# %% [markdown]
# # Square Model

# %%
# Import Libraries

import numpy as np
import scipy
import matplotlib.pyplot as plt
from pprint import pprint

np.set_printoptions(precision=5, suppress=True, linewidth=100)

import tenpy
import tenpy.linalg.np_conserved as npc
from tenpy.algorithms import tebd, dmrg, tdvp
from tenpy.networks.site import SpinHalfSite, SpinSite, FermionSite
from tenpy.networks.mps import MPS
from tenpy.models.tf_ising import TFIChain
from tenpy.algorithms.dmrg import DMRGEngine, TwoSiteDMRGEngine
from tenpy.algorithms.exact_diag import ExactDiag

tenpy.tools.misc.setup_logging(to_stdout="INFO")

import tenpy.linalg.np_conserved as npc
from tenpy.networks.site import SpinHalfSite
from tenpy.networks.mps import MPS
from tenpy.networks.mpo import MPO
from tenpy.networks.site import SpinSite
from tenpy.models.lattice import Chain
from tenpy.models.model import CouplingModel, NearestNeighborModel, MPOModel, CouplingMPOModel
from tenpy.models.spins import SpinModel, SpinChain
from tenpy.models import Lattice

# %%
def _parse_sites(sites, expected_number):
    try: 
        iter(sites)
    except TypeError:
        return [sites] * expected_number
    if len(sites) != expected_number:
        raise ValueError("need to specify a single site or exactly {0:d}, got {1:d}".format(expected_number, len(sites)))
    return sites

# %%
class Square(Lattice):
    dim = 2
    Lu = 1

    def __init__(self, Lx, Ly, sites, **kwargs):
        sites = _parse_sites(sites, 1)
        a1 = np.array([1, 0])
        a2 = np.array([0, 1])
        basis = np.array([a1, a2])
        
        A = np.array([0.0, 0.0])

        pos = [A]
        
        kwargs.setdefault("basis", basis)
        kwargs.setdefault("positions", pos)
        kwargs.setdefault('pairs', {})

        NN = []
        
        NN.append((0, 0, np.array([0, 1])))
        NN.append((0, 0, np.array([1, 0])))
        
        kwargs.setdefault("pairs", {})
        kwargs["pairs"].setdefault("nearest_neighbors", NN)

        nNN = []
        
        nNN.append((0, 0, np.array([1, 1])))
        nNN.append((0, 0, np.array([-1, 1])))

        kwargs["pairs"].setdefault("next_nearest_neighbors", nNN)

        Lattice.__init__(self, [Lx, Ly], sites, **kwargs)

# %%
sq = Square(4, 4, None)

# %%
plt.figure(figsize=(6, 6))
plt.title("Square Lattice")
ax = plt.gca()
sq.plot_sites(ax)
sq.plot_coupling(ax)
sq.plot_order(ax, linestyle=":")
sq.plot_basis(ax)
ax.set_aspect("equal")
ax.set_xlim(-1)
ax.set_ylim(-1)
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.title("NN")
ax = plt.gca()
sq.plot_sites(ax)
sq.plot_coupling(ax)
ax.set_aspect("equal")
ax.set_xlim(-1)
ax.set_ylim(-1)
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.title("nNN")
ax = plt.gca()
sq.plot_sites(ax)
sq.plot_coupling(ax, coupling=sq.pairs["next_nearest_neighbors"])
ax.set_aspect("equal")
ax.set_xlim(-1)
ax.set_ylim(-1)
plt.show()

# %%
class IsingModel(CouplingMPOModel):
    def init_sites(self, model_params):
        conserve = model_params.get("conserve", "best")
        if conserve == "best":
            if model_params.get("hx", 0) == 0:
                conserve = "Sz"
            else:
                conserve = None
        return SpinHalfSite(conserve=conserve)

# %%
class SquareModel(IsingModel):
    default_lattice = Square
    force_default_lattice = True

    def init_sites(self, model_params):
        site = IsingModel.init_sites(self, model_params)
        return (site)

    def init_terms(self, model_params):
        J1 = model_params.get("J1", 1)
        J2 = model_params.get("J2", 1)

        for u1, u2, dx in self.lat.pairs["nearest_neighbors"]:
            self.add_coupling(J1, u1, "Sz", u2, "Sz", dx)

        for u1, u2, dx in self.lat.pairs["next_nearest_neighbors"]:
            self.add_coupling(J2, u1, "Sz", u2, "Sz", dx)

# %%
sq_model = SquareModel({"Lx": 4, "Ly": 4, "J1": 1, "J2": 0, 'bc_MPS': 'finite'})
# Out:
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=4
# INFO    : SquareModel: reading 'Ly'=4
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0

# %%
J2_arr = np.linspace(0, 1, 100)
E0_arr = np.array([])
Sz_arr = np.array([])

for J2 in J2_arr:
    sq_model = SquareModel({"Lx": 3, "Ly": 3, "J1": 1, "J2": J2, 'bc_MPS': 'finite'})
    sq_ed = ExactDiag(sq_model)
    sq_ed.build_full_H_from_mpo()
    sq_ed.full_diagonalization()
    E0, psi0 = sq_ed.groundstate()
    E0_arr = np.append(E0_arr, E0)
# Out:
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.0
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.010101010101010102
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.020202020202020204
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.030303030303030304
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.04040404040404041
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.05050505050505051
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.06060606060606061
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.07070707070707072
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.08080808080808081
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.09090909090909091
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.10101010101010102
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.11111111111111112
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.12121212121212122
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.13131313131313133
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.14141414141414144
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.15151515151515152
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.16161616161616163
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.17171717171717174
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.18181818181818182
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.19191919191919193
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.20202020202020204
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.21212121212121213
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.22222222222222224
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.23232323232323235
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.24242424242424243
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.25252525252525254
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.26262626262626265
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.27272727272727276
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.2828282828282829
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.29292929292929293
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.30303030303030304
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.31313131313131315
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.32323232323232326
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.33333333333333337
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.3434343434343435
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.3535353535353536
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.36363636363636365
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.37373737373737376
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.38383838383838387
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.393939393939394
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.4040404040404041
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.4141414141414142
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.42424242424242425
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.43434343434343436
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.4444444444444445
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.4545454545454546
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.4646464646464647
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.4747474747474748
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.48484848484848486
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.494949494949495
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5050505050505051
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5151515151515152
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5252525252525253
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5353535353535354
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5454545454545455
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5555555555555556
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5656565656565657
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5757575757575758
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5858585858585859
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.595959595959596
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6060606060606061
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6161616161616162
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6262626262626263
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6363636363636365
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6464646464646465
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6565656565656566
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6666666666666667
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6767676767676768
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.686868686868687
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.696969696969697
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7070707070707072
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7171717171717172
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7272727272727273
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7373737373737375
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7474747474747475
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7575757575757577
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7676767676767677
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7777777777777778
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.787878787878788
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.797979797979798
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8080808080808082
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8181818181818182
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8282828282828284
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8383838383838385
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8484848484848485
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8585858585858587
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8686868686868687
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8787878787878789
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.888888888888889
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8989898989898991
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9090909090909092
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9191919191919192
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9292929292929294
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9393939393939394
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9494949494949496
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9595959595959597
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9696969696969697
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9797979797979799
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.98989898989899
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=3
# INFO    : SquareModel: reading 'Ly'=3
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=1.0

# %%
plt.figure(figsize=(6, 6))
plt.plot(J2_arr, E0_arr)
plt.title("Site")
plt.xlabel("J2")
plt.ylabel("E0")
plt.show()

# %%
J2_arr = np.linspace(0, 1, 100)
E0_arr = np.array([])
Sz_arr = np.array([])

for J2 in J2_arr:
    sq_model = SquareModel({"Lx": 2, "Ly": 2, "J1": 1, "J2": J2, 'bc_MPS': 'finite'})
    sq_ed = ExactDiag(sq_model)
    sq_ed.build_full_H_from_mpo()
    sq_ed.full_diagonalization()
    E0, psi0 = sq_ed.groundstate()
    E0_arr = np.append(E0_arr, E0)
# Out:
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.0
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.010101010101010102
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.020202020202020204
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.030303030303030304
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.04040404040404041
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.05050505050505051
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.06060606060606061
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.07070707070707072
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.08080808080808081
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.09090909090909091
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.10101010101010102
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.11111111111111112
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.12121212121212122
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.13131313131313133
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.14141414141414144
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.15151515151515152
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.16161616161616163
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.17171717171717174
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.18181818181818182
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.19191919191919193
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.20202020202020204
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.21212121212121213
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.22222222222222224
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.23232323232323235
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.24242424242424243
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.25252525252525254
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.26262626262626265
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.27272727272727276
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.2828282828282829
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.29292929292929293
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.30303030303030304
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.31313131313131315
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.32323232323232326
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.33333333333333337
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.3434343434343435
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.3535353535353536
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.36363636363636365
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.37373737373737376
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.38383838383838387
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.393939393939394
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.4040404040404041
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.4141414141414142
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.42424242424242425
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.43434343434343436
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.4444444444444445
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.4545454545454546
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.4646464646464647
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.4747474747474748
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.48484848484848486
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.494949494949495
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5050505050505051
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5151515151515152
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5252525252525253
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5353535353535354
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5454545454545455
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5555555555555556
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5656565656565657
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5757575757575758
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.5858585858585859
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.595959595959596
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6060606060606061
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6161616161616162
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6262626262626263
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6363636363636365
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6464646464646465
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6565656565656566
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6666666666666667
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.6767676767676768
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.686868686868687
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.696969696969697
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7070707070707072
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7171717171717172
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7272727272727273
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7373737373737375
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7474747474747475
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7575757575757577
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7676767676767677
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.7777777777777778
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.787878787878788
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.797979797979798
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8080808080808082
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8181818181818182
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8282828282828284
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8383838383838385
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8484848484848485
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8585858585858587
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8686868686868687
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8787878787878789
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.888888888888889
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.8989898989898991
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9090909090909092
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9191919191919192
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9292929292929294
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9393939393939394
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9494949494949496
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9595959595959597
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9696969696969697
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9797979797979799
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.98989898989899
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'Lx'=2
# INFO    : SquareModel: reading 'Ly'=2
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=1.0

# %%
plt.figure(figsize=(6, 6))
plt.plot(J2_arr, E0_arr)
plt.title("Site")
plt.xlabel("J2")
plt.ylabel("E0")
plt.show()

# %%
# Return a random up or down spin
def random_spin():
    return "up" if np.random.random() < 0.5 else "down"

# %%
J2_arr = np.linspace(0, 1, 100)
E0_arr = np.array([])

for J2 in J2_arr:
    sq_model = SquareModel({"Lx": 10, "Ly": 10, "J1": 1, "J2": J2, 'bc_MPS': 'finite', 'bc_x': 'open', 'bc_y': 'open'})
    p_state = [random_spin() for _ in np.arange(sq_model.lat.N_sites)]
    psi = MPS.from_product_state(sq_model.lat.mps_sites(), p_state, "finite")
    algorithm_params = {'trunc_params': {'chi_max': 100, 'svd_min': 1e-10}, "mixer": True}
    eng = TwoSiteDMRGEngine(psi, sq_model, algorithm_params)
    E, psi = eng.run()
    E0_arr = np.append(E0_arr, E)
# Out:
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.0
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-18.0000000000000000, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 553.7MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 0.0000e+00
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-19.5000000000000000, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 553.8MB, wall time: 0.6s
# Delta E = -1.5000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 0.0000e+00
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-19.5000000000000000, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 553.8MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 0.0000e+00
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-19.5000000000000000, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 553.8MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 0.0000e+00
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.010101010101010102
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-22.3484848484848442, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.0MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 0.0000e+00
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-24.3282828282828234, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.0MB, wall time: 0.5s
# Delta E = -1.9798e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 0.0000e+00
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-24.3282828282828234, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.1MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 0.0000e+00
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-24.3282828282828234, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.1MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 0.0000e+00
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.020202020202020204
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-19.2474747474747439, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.7764e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-19.2474747474747439, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 0.0000e+00
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 2.5e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-20.6868686868686780, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = -1.4394e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-21.6666666666666607, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = -9.7980e-01, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-21.6666666666666607, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 5 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.030303030303030304
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-15.8636363636363598, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.7764e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-21.2121212121212039, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -5.3485e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-21.2121212121212039, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-21.2121212121212039, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.04040404040404041
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-22.9343434343434254, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-23.8535353535353423, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = -9.1919e-01, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-23.8535353535353423, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-23.8535353535353423, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.05050505050505051
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-16.0959595959595916, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-19.4191919191919133, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.7s
# Delta E = -3.3232e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-19.9696969696969653, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = -5.5051e-01, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-21.3686868686868614, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = -1.3990e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-21.3686868686868614, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 3.125e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 6
# energy=-21.3686868686868614, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 6 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.06060606060606061
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-20.8333333333333250, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-22.2121212121212004, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -1.3788e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-22.2121212121212004, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-22.2121212121212004, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.07070707070707072
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-14.7575757575757667, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-19.4040404040404084, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -4.6465e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-20.2626262626262665, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -8.5859e-01, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-20.2626262626262665, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 6.25e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-20.2626262626262665, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 5 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.08080808080808081
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-14.9747474747474794, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.7764e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-15.8131313131313114, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -8.3838e-01, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-15.8131313131313114, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-15.8131313131313114, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.09090909090909091
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-13.8636363636363686, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-18.8636363636363669, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -5.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-18.8636363636363669, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-18.8636363636363669, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.10101010101010102
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-20.5858585858585741, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-24.1818181818181621, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -3.5960e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.0658e-14
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-25.0808080808080582, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -8.9899e-01, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.0658e-14
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-25.0808080808080582, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 6.25e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-25.0808080808080582, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 5 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.11111111111111112
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-18.9999999999999858, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-19.7777777777777608, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -7.7778e-01, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-19.7777777777777608, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-19.7777777777777608, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.12121212121212122
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-17.2727272727272663, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-17.7121212121212039, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -4.3939e-01, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-17.7121212121212039, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-17.7121212121212039, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.13131313131313133
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-22.2020202020202184, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-24.2424242424242635, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -2.0404e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-24.9797979797980005, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -7.3737e-01, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-24.9797979797980005, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 6.25e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-24.9797979797980005, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 5 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.14141414141414144
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-15.3686868686868667, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-19.1616161616161591, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -3.7929e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-19.8787878787878824, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -7.1717e-01, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-19.8787878787878824, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 6.25e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-19.8787878787878824, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 5 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.15151515151515152
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-15.3636363636363615, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-15.3636363636363615, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.7764e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 2.5e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-15.3636363636363615, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.7764e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 3 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.16161616161616163
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-16.9797979797979792, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-17.3181818181818166, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -3.3838e-01, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-17.3181818181818166, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-17.3181818181818166, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.17171717171717174
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-18.5959595959595845, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-21.1515151515151558, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -2.5556e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-21.1515151515151558, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-21.1515151515151558, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.18181818181818182
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-18.9545454545454497, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-21.4090909090909101, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -2.4545e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# ...
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -9.3939e-01, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-19.4999999999999858, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-19.4999999999999858, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9494949494949496
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-20.7929292929292764, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-24.0404040404040167, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -3.2475e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-24.0404040404040167, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-24.0404040404040167, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9595959595959597
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-13.0959595959595951, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-14.0959595959595898, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -1.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.7764e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-14.0959595959595898, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.7764e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-14.0959595959595898, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.7764e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9696969696969697
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-18.6060606060605984, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.7764e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-22.5151515151515014, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -3.9091e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-22.5151515151515014, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-22.5151515151515014, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.9797979797979799
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-20.7676767676767611, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-26.0656565656565569, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -5.2980e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-28.4848484848484738, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -2.4192e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-28.4848484848484738, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 6.25e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-28.4848484848484738, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 5 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=0.98989898989899
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-21.3585858585858546, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 1.7764e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-22.8282828282828270, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = -1.4697e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-22.8282828282828270, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-22.8282828282828270, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-15
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=1
# INFO    : SquareModel: reading 'bc_MPS'='finite'
# INFO    : SquareModel: reading 'bc_x'='open'
# INFO    : SquareModel: reading 'Lx'=10
# INFO    : SquareModel: reading 'Ly'=10
# INFO    : SquareModel: reading 'bc_y'='open'
# INFO    : SquareModel: reading 'J1'=1
# INFO    : SquareModel: reading 'J2'=1.0
# INFO    : TwoSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : TwoSiteDMRGEngine: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-19.5000000000000000, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.6s
# Delta E = nan, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 0.0000e+00
# chi: 1
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-19.5000000000000000, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.5s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 0.0000e+00
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 2.5e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-19.5000000000000000, max S=-0.0000000000000000, age=100, norm_err=0.0e+00
# Current memory usage 554.3MB, wall time: 0.4s
# Delta E = 0.0000e+00, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 0.0000e+00
# chi: 1
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 3 sweeps, max chi=1

# %%
plt.figure(figsize=(6, 6))
plt.plot(J2_arr, E0_arr)
plt.title("Site")
plt.xlabel("J2")
plt.ylabel("E0")
plt.show()
