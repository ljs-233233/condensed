# %% [markdown]
# # 1D Heisenberg Model
# 1D Heisenberg Model with Tenpy

# %%
# Import Libraries

import numpy as np
import scipy
import matplotlib.pyplot as plt
from pprint import pprint

np.set_printoptions(precision=5, suppress=True, linewidth=100)

import tenpy
import tenpy.linalg.np_conserved as npc
from tenpy.algorithms import tebd, dmrg, tdvp
from tenpy.networks.site import SpinHalfSite, SpinSite, FermionSite
from tenpy.networks.mps import MPS
from tenpy.models.tf_ising import TFIChain
from tenpy.algorithms import dmrg

tenpy.tools.misc.setup_logging(to_stdout="INFO")

import tenpy.linalg.np_conserved as npc
from tenpy.networks.site import SpinHalfSite
from tenpy.networks.mps import MPS
from tenpy.networks.mpo import MPO
from tenpy.networks.site import SpinSite
from tenpy.models.lattice import Chain
from tenpy.models.model import CouplingModel, NearestNeighborModel, MPOModel
from tenpy.models.spins import SpinModel
from tenpy.models import lattice

# %%
spin = SpinHalfSite(conserve="Sz")
Sz = spin.Sz

# %%
N = 10
model = TFIChain({"L": N, "J": 1., "g": 1., "bc_MPS": "finite"})
sites = model.lat.mps_sites()
psi = MPS.from_product_state(sites, ['up'] * N, "finite")
dmrg_params = {"trunc_params": {"chi_max": 100, "svd_min": 1.e-10}, "mixer": True}
info = dmrg.run(psi, model, dmrg_params)
print("E =", info['E'])
print("max. bond dimension =", max(psi.chi))
# Out:
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1.0
# INFO    : TFIChain: reading 'g'=1.0
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-12.3814899996540024, max S=0.3769920957020116, age=10, norm_err=3.1e-02
# Current memory usage 174.9MB, wall time: 0.5s
# Delta E = nan, Delta S = 3.2977e-01 (per sweep)
# max trunc_err = 6.2556e-21, max E_trunc = 2.3093e-14
# chi: [2, 4, 8, 11, 12, 12, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-12.3814899996547521, max S=0.3790524054180356, age=10, norm_err=6.0e-12
# Current memory usage 179.9MB, wall time: 0.7s
# Delta E = -7.4962e-13, Delta S = 7.3113e-03 (per sweep)
# max trunc_err = 1.3361e-20, max E_trunc = 1.5987e-14
# chi: [2, 4, 8, 15, 23, 15, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-12.3814899996547503, max S=0.3790524054180266, age=10, norm_err=6.3e-14
# Current memory usage 184.0MB, wall time: 0.6s
# Delta E = 1.7764e-15, Delta S = -5.9609e-07 (per sweep)
# max trunc_err = 1.7954e-20, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 16, 19, 14, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-12.3814899996547325, max S=0.3790524054180259, age=10, norm_err=4.5e-15
# Current memory usage 186.0MB, wall time: 0.6s
# Delta E = 1.7764e-14, Delta S = -5.9610e-07 (per sweep)
# max trunc_err = 9.9291e-21, max E_trunc = 1.7764e-14
# chi: [2, 4, 8, 14, 19, 14, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=19
# E = -12.381489999654733
# max. bond dimension = 19

# %%
g_arr = np.linspace(0, 2, 100)

def sim(g):
    N = 10
    model = TFIChain({"L": N, "J": 1, "g": g, "bc_MPS": "finite"})
    sites = model.lat.mps_sites()
    psi = MPS.from_product_state(sites, ['up'] * N, "finite")
    dmrg_params = {"trunc_params": {"chi_max": 100, "svd_min": 1.e-10}, "mixer": True}
    info = dmrg.run(psi, model, dmrg_params)
    return np.mean(psi.expectation_value("Sz"))

Sz_arr = np.array([sim(g) for g in g_arr])
# Out:
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.0
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 1
# energy=-9.0000000000000000, max S=0.6931471805599527, age=10, norm_err=5.7e-15
# Current memory usage 186.1MB, wall time: 0.1s
# Delta E = nan, Delta S = 6.9315e-01 (per sweep)
# max trunc_err = 3.6082e-21, max E_trunc = 5.3291e-15
# chi: [2, 2, 2, 3, 3, 3, 2, 3, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.0000000000000089, max S=0.6931471805599494, age=10, norm_err=5.2e-15
# Current memory usage 186.1MB, wall time: 0.1s
# Delta E = -8.8818e-15, Delta S = 0.0000e+00 (per sweep)
# max trunc_err = 3.0531e-21, max E_trunc = 3.5527e-15
# chi: [2, 2, 2, 2, 2, 3, 3, 2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 2.5e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-8.9999999999999982, max S=0.6931471805599453, age=10, norm_err=2.7e-15
# Current memory usage 186.1MB, wall time: 0.1s
# Delta E = 1.0658e-14, Delta S = -1.5543e-15 (per sweep)
# max trunc_err = 4.5713e-31, max E_trunc = 5.3291e-15
# chi: [2, 2, 2, 2, 2, 2, 2, 2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 3 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.020202020202020204
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 1
# energy=-9.0012244013007070, max S=0.6931471949791874, age=10, norm_err=1.4e-02
# Current memory usage 186.1MB, wall time: 0.1s
# Delta E = nan, Delta S = 6.9303e-01 (per sweep)
# max trunc_err = 2.6255e-21, max E_trunc = 5.3291e-15
# chi: [2, 4, 6, 7, 7, 6, 6, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.0012244013007017, max S=0.6931471949791913, age=10, norm_err=6.5e-13
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 5.3291e-15, Delta S = 6.7895e-05 (per sweep)
# max trunc_err = 1.9393e-21, max E_trunc = 7.1054e-15
# chi: [2, 4, 7, 6, 8, 7, 7, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.0012244013007034, max S=0.6931471949791962, age=10, norm_err=2.9e-12
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -1.7764e-15, Delta S = -2.2674e-10 (per sweep)
# max trunc_err = 6.8058e-21, max E_trunc = 5.3291e-15
# chi: [2, 4, 6, 8, 8, 7, 7, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.0012244013006946, max S=0.6931471949791860, age=10, norm_err=4.2e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = 8.8818e-15, Delta S = -2.2674e-10 (per sweep)
# max trunc_err = 5.5539e-28, max E_trunc = 7.1054e-15
# chi: [2, 4, 6, 6, 6, 6, 6, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=6
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.04040404040404041
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=6.422586652624378e-22
# INFO    : checkpoint after sweep 1
# energy=-9.0048980426864329, max S=0.6931473826274188, age=10, norm_err=2.8e-02
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = nan, Delta S = 6.9270e-01 (per sweep)
# max trunc_err = 1.2845e-20, max E_trunc = 7.1054e-15
# chi: [2, 4, 8, 7, 8, 7, 7, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.0048980426864365, max S=0.6931473826274781, age=10, norm_err=4.0e-13
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = -3.5527e-15, Delta S = 2.7012e-04 (per sweep)
# max trunc_err = 1.3272e-20, max E_trunc = 1.7764e-15
# chi: [2, 4, 8, 7, 8, 8, 7, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.0048980426864311, max S=0.6931473826274760, age=10, norm_err=7.0e-13
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = 5.3291e-15, Delta S = -9.0705e-10 (per sweep)
# max trunc_err = 1.2033e-20, max E_trunc = 7.1054e-15
# chi: [2, 4, 7, 7, 7, 7, 7, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.0048980426864258, max S=0.6931473826274758, age=10, norm_err=4.0e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = 5.3291e-15, Delta S = -9.0706e-10 (per sweep)
# max trunc_err = 2.2650e-24, max E_trunc = 7.1054e-15
# chi: [2, 4, 6, 6, 6, 6, 6, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=6
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.06060606060606061
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 1
# energy=-9.0110222381421821, max S=0.6931481197206779, age=10, norm_err=4.2e-02
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = nan, Delta S = 6.9214e-01 (per sweep)
# max trunc_err = 8.6812e-21, max E_trunc = 5.3291e-15
# chi: [2, 4, 8, 9, 7, 8, 7, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.0110222381422052, max S=0.6931481197218553, age=10, norm_err=1.7e-13
# Current memory usage 186.1MB, wall time: 1.6s
# Delta E = -2.3093e-14, Delta S = 6.0235e-04 (per sweep)
# max trunc_err = 3.7891e-21, max E_trunc = 1.7764e-14
# chi: [2, 4, 6, 9, 7, 9, 7, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.0110222381421980, max S=0.6931481197218577, age=10, norm_err=1.2e-13
# Current memory usage 186.1MB, wall time: 0.8s
# Delta E = 7.1054e-15, Delta S = -2.0412e-09 (per sweep)
# max trunc_err = 8.1223e-21, max E_trunc = 1.0658e-14
# chi: [2, 4, 6, 9, 7, 7, 6, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.0110222381421750, max S=0.6931481197218544, age=10, norm_err=9.2e-15
# Current memory usage 186.1MB, wall time: 1.3s
# Delta E = 2.3093e-14, Delta S = -2.0412e-09 (per sweep)
# max trunc_err = 2.9556e-22, max E_trunc = 8.8818e-15
# chi: [2, 4, 6, 6, 6, 6, 6, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=6
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.08080808080808081
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 1
# energy=-9.0195991827783377, max S=0.6931499638613966, age=10, norm_err=5.6e-02
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 6.9136e-01 (per sweep)
# max trunc_err = 8.7603e-21, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 7, 7, 10, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.0195991827783288, max S=0.6931499638743692, age=10, norm_err=2.6e-14
# Current memory usage 186.1MB, wall time: 1.0s
# Delta E = 8.8818e-15, Delta S = 1.0576e-03 (per sweep)
# max trunc_err = 1.6266e-20, max E_trunc = 1.2434e-14
# chi: [2, 4, 7, 8, 8, 9, 7, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.0195991827783448, max S=0.6931499638743753, age=10, norm_err=2.3e-12
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = -1.5987e-14, Delta S = -3.6297e-09 (per sweep)
# max trunc_err = 2.0418e-20, max E_trunc = 5.3291e-15
# chi: [2, 4, 7, 6, 9, 8, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.0195991827783324, max S=0.6931499638743681, age=10, norm_err=4.0e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = 1.2434e-14, Delta S = -3.6297e-09 (per sweep)
# max trunc_err = 9.3778e-21, max E_trunc = 7.1054e-15
# chi: [2, 4, 6, 6, 6, 6, 6, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=6
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.10101010101010102
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 1
# energy=-9.0306319606320820, max S=0.6931536325014290, age=10, norm_err=6.9e-02
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = nan, Delta S = 6.9038e-01 (per sweep)
# max trunc_err = 9.6357e-21, max E_trunc = 7.9936e-15
# chi: [2, 4, 8, 6, 10, 9, 7, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.0306319606320802, max S=0.6931536325550813, age=10, norm_err=1.2e-12
# Current memory usage 186.1MB, wall time: 0.9s
# Delta E = 1.7764e-15, Delta S = 1.6265e-03 (per sweep)
# max trunc_err = 8.7277e-21, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 9, 10, 11, 6, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.0306319606320731, max S=0.6931536325550895, age=10, norm_err=2.2e-12
# Current memory usage 186.1MB, wall time: 1.0s
# Delta E = 7.1054e-15, Delta S = -5.6731e-09 (per sweep)
# max trunc_err = 6.8738e-21, max E_trunc = 1.0658e-14
# chi: [2, 4, 7, 12, 12, 10, 7, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.0306319606320820, max S=0.6931536325550829, age=10, norm_err=3.6e-15
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = -8.8818e-15, Delta S = -5.6732e-09 (per sweep)
# max trunc_err = 4.0014e-26, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 10, 10, 10, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.12121212121212122
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 1
# energy=-9.0441245558583638, max S=0.6931599911158047, age=10, norm_err=8.1e-02
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 6.8920e-01 (per sweep)
# max trunc_err = 7.8288e-21, max E_trunc = 7.1054e-15
# chi: [2, 4, 7, 9, 10, 7, 7, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.0441245558583585, max S=0.6931599913350817, age=10, norm_err=1.1e-12
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = 5.3291e-15, Delta S = 2.2976e-03 (per sweep)
# max trunc_err = 6.8087e-21, max E_trunc = 7.1054e-15
# chi: [2, 4, 6, 10, 13, 12, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.0441245558583727, max S=0.6931599913350799, age=10, norm_err=2.4e-12
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = -1.4211e-14, Delta S = -8.1723e-09 (per sweep)
# max trunc_err = 2.3503e-21, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 9, 13, 9, 7, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.0441245558583585, max S=0.6931599913350768, age=10, norm_err=7.6e-15
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = 1.4211e-14, Delta S = -8.1724e-09 (per sweep)
# max trunc_err = 8.4003e-25, max E_trunc = 8.8818e-15
# chi: [2, 4, 8, 10, 10, 10, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.14141414141414144
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.322866790040424e-22
# INFO    : checkpoint after sweep 1
# energy=-9.0600818677438149, max S=0.6931700460578554, age=10, norm_err=9.3e-02
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 6.8784e-01 (per sweep)
# max trunc_err = 1.0646e-20, max E_trunc = 1.0658e-14
# chi: [2, 4, 7, 11, 12, 11, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.0600818677438326, max S=0.6931700468911084, age=10, norm_err=2.7e-12
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = -1.7764e-14, Delta S = 3.0579e-03 (per sweep)
# max trunc_err = 1.0157e-20, max E_trunc = 5.3291e-15
# chi: [2, 4, 6, 12, 11, 10, 7, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.0600818677438255, max S=0.6931700468911157, age=10, norm_err=5.8e-13
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = 7.1054e-15, Delta S = -1.1128e-08 (per sweep)
# max trunc_err = 1.2969e-20, max E_trunc = 1.2434e-14
# chi: [2, 4, 6, 11, 13, 11, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.0600818677438220, max S=0.6931700468911037, age=10, norm_err=1.0e-14
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 3.5527e-15, Delta S = -1.1129e-08 (per sweep)
# max trunc_err = 2.0290e-23, max E_trunc = 5.3291e-15
# chi: [2, 4, 8, 10, 10, 10, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.16161616161616163
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.606746140212027e-22
# INFO    : checkpoint after sweep 1
# energy=-9.0785097303264095, max S=0.6931849416329976, age=10, norm_err=1.0e-01
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 6.8631e-01 (per sweep)
# max trunc_err = 1.1213e-20, max E_trunc = 1.0658e-14
# chi: [2, 4, 7, 10, 12, 9, 7, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.0785097303264077, max S=0.6931849417258446, age=10, norm_err=2.7e-13
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 1.7764e-15, Delta S = 3.8934e-03 (per sweep)
# max trunc_err = 1.7810e-20, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 12, 11, 12, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.0785097303264184, max S=0.6931849417258475, age=10, norm_err=6.2e-13
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = -1.0658e-14, Delta S = -1.4543e-08 (per sweep)
# max trunc_err = 1.3287e-20, max E_trunc = 7.1054e-15
# chi: [2, 4, 8, 11, 11, 10, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.0785097303264113, max S=0.6931849417258441, age=10, norm_err=1.2e-14
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = 7.1054e-15, Delta S = -1.4543e-08 (per sweep)
# max trunc_err = 7.3903e-23, max E_trunc = 7.1054e-15
# chi: [2, 4, 8, 10, 10, 10, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.18181818181818182
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.177446308814651e-22
# INFO    : checkpoint after sweep 1
# energy=-9.0994149379026386, max S=0.6932059412005975, age=10, norm_err=1.1e-01
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 6.8462e-01 (per sweep)
# max trunc_err = 1.0355e-20, max E_trunc = 1.2434e-14
# chi: [2, 4, 8, 10, 10, 9, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.0994149379026439, max S=0.6932059473861683, age=10, norm_err=2.7e-13
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = -5.3291e-15, Delta S = 4.7892e-03 (per sweep)
# max trunc_err = 2.1938e-21, max E_trunc = 1.4211e-14
# chi: [2, 4, 8, 12, 12, 12, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.0994149379026368, max S=0.6932059473861669, age=10, norm_err=1.1e-13
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 7.1054e-15, Delta S = -1.8416e-08 (per sweep)
# max trunc_err = 5.1363e-21, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 11, 12, 10, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.0994149379026421, max S=0.6932059473861639, age=10, norm_err=6.8e-15
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = -5.3291e-15, Delta S = -1.8416e-08 (per sweep)
# max trunc_err = 5.4911e-22, max E_trunc = 7.1054e-15
# chi: [2, 4, 8, 10, 10, 10, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.20202020202020204
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 1
# energy=-9.1228052783683236, max S=0.6932344371390617, age=10, norm_err=1.2e-01
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 6.8277e-01 (per sweep)
# max trunc_err = 7.9518e-21, max E_trunc = 1.2434e-14
# chi: [2, 4, 8, 11, 12, 10, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.1228052783683200, max S=0.6932344518703127, age=10, norm_err=2.5e-13
# Current memory usage 186.1MB, wall time: 1.1s
# Delta E = 3.5527e-15, Delta S = 5.7304e-03 (per sweep)
# max trunc_err = 9.9260e-21, max E_trunc = 7.1054e-15
# chi: [2, 4, 8, 11, 10, 12, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.1228052783683236, max S=0.6932344518703171, age=10, norm_err=1.1e-14
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -3.5527e-15, Delta S = -2.2751e-08 (per sweep)
# max trunc_err = 9.2047e-21, max E_trunc = 3.5527e-15
# chi: [2, 4, 8, 12, 12, 13, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.1228052783683378, max S=0.6932344518703133, age=10, norm_err=7.6e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -1.4211e-14, Delta S = -2.2751e-08 (per sweep)
# max trunc_err = 2.3195e-21, max E_trunc = 5.3291e-15
# chi: [2, 4, 8, 10, 10, 10, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.22222222222222224
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-9.1486895771675645, max S=0.6932719186449487, age=10, norm_err=1.3e-01
# Current memory usage 186.1MB, wall time: 0.8s
# Delta E = nan, Delta S = 6.8079e-01 (per sweep)
# max trunc_err = 1.0494e-20, max E_trunc = 7.1054e-15
# chi: [2, 4, 8, 12, 11, 11, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.1486895771675592, max S=0.6932719351252183, age=10, norm_err=1.9e-13
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = 5.3291e-15, Delta S = 6.7019e-03 (per sweep)
# max trunc_err = 1.6143e-20, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 12, 13, 11, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.1486895771675627, max S=0.6932719351252156, age=10, norm_err=2.0e-14
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = -3.5527e-15, Delta S = -2.7549e-08 (per sweep)
# max trunc_err = 1.3276e-20, max E_trunc = 8.8818e-15
# chi: [2, 4, 8, 13, 11, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.1486895771675556, max S=0.6932719351252150, age=10, norm_err=4.1e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 7.1054e-15, Delta S = -2.7549e-08 (per sweep)
# max trunc_err = 1.0508e-20, max E_trunc = 1.2434e-14
# chi: [2, 4, 8, 10, 10, 10, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.24242424242424243
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-9.1770777556063550, max S=0.6933198341674396, age=10, norm_err=1.4e-01
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 6.7869e-01 (per sweep)
# max trunc_err = 1.2528e-20, max E_trunc = 5.3291e-15
# chi: [2, 4, 8, 11, 11, 9, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.1770777556063692, max S=0.6933199240766615, age=10, norm_err=3.5e-13
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = -1.4211e-14, Delta S = 7.6894e-03 (per sweep)
# max trunc_err = 4.8383e-21, max E_trunc = 1.5987e-14
# chi: [2, 4, 8, 11, 15, 13, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.1770777556063621, max S=0.6933199240766650, age=10, norm_err=4.4e-13
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = 7.1054e-15, Delta S = -3.2812e-08 (per sweep)
# max trunc_err = 1.6871e-20, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 12, 15, 13, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.1770777556063567, max S=0.6933199240766553, age=10, norm_err=6.8e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = 5.3291e-15, Delta S = -3.2812e-08 (per sweep)
# max trunc_err = 8.7552e-21, max E_trunc = 7.1054e-15
# chi: [2, 4, 8, 12, 12, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=12
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.26262626262626265
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.537249288639772e-22
# INFO    : checkpoint after sweep 1
# energy=-9.2079809083919830, max S=0.6933797091080660, age=10, norm_err=1.4e-01
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = nan, Delta S = 6.7646e-01 (per sweep)
# max trunc_err = 1.1074e-20, max E_trunc = 7.1054e-15
# chi: [2, 4, 8, 8, 8, 10, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.2079809083919741, max S=0.6933799154877942, age=10, norm_err=8.4e-13
# Current memory usage 186.1MB, wall time: 0.8s
# Delta E = 8.8818e-15, Delta S = 8.6792e-03 (per sweep)
# max trunc_err = 8.4194e-21, max E_trunc = 3.5527e-15
# chi: [2, 4, 8, 11, 16, 14, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.2079809083919812, max S=0.6933799154878003, age=10, norm_err=6.3e-13
# Current memory usage 186.1MB, wall time: 1.1s
# Delta E = -7.1054e-15, Delta S = -3.8542e-08 (per sweep)
# max trunc_err = 9.8063e-21, max E_trunc = 1.2434e-14
# chi: [2, 4, 8, 13, 17, 14, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.2079809083919937, max S=0.6933799154877892, age=10, norm_err=1.1e-14
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -1.2434e-14, Delta S = -3.8543e-08 (per sweep)
# max trunc_err = 7.5383e-24, max E_trunc = 3.5527e-15
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.2828282828282829
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 1
# energy=-9.2414114064383011, max S=0.6934529311333808, age=10, norm_err=1.5e-01
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 6.7413e-01 (per sweep)
# max trunc_err = 7.2079e-21, max E_trunc = 1.7764e-14
# chi: [2, 4, 8, 10, 11, 12, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.2414114064382993, max S=0.6934532510758165, age=10, norm_err=5.9e-13
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 1.7764e-15, Delta S = 9.6590e-03 (per sweep)
# max trunc_err = 6.7620e-21, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 12, 15, 13, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.2414114064383117, max S=0.6934532510758197, age=10, norm_err=3.7e-13
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = -1.2434e-14, Delta S = -4.4744e-08 (per sweep)
# max trunc_err = 9.8693e-21, max E_trunc = 8.8818e-15
# chi: [2, 4, 8, 12, 16, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.2414114064383082, max S=0.6934532510758153, age=10, norm_err=6.4e-15
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 3.5527e-15, Delta S = -4.4744e-08 (per sweep)
# max trunc_err = 1.2696e-23, max E_trunc = 8.8818e-15
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.30303030303030304
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-9.2773830321601398, max S=0.6935408174692009, age=10, norm_err=1.5e-01
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = nan, Delta S = 6.7169e-01 (per sweep)
# max trunc_err = 9.3621e-21, max E_trunc = 3.5527e-15
# chi: [2, 4, 8, 13, 15, 12, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.2773830321601238, max S=0.6935409247162371, age=10, norm_err=1.4e-12
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 1.5987e-14, Delta S = 1.0616e-02 (per sweep)
# max trunc_err = 1.6347e-20, max E_trunc = 5.3291e-15
# chi: [2, 4, 8, 12, 16, 13, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.2773830321601185, max S=0.6935409247162378, age=10, norm_err=2.0e-13
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 5.3291e-15, Delta S = -5.1419e-08 (per sweep)
# max trunc_err = 1.3795e-20, max E_trunc = 8.8818e-15
# chi: [2, 4, 8, 13, 14, 14, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.2773830321601274, max S=0.6935409247162365, age=10, norm_err=4.4e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = -8.8818e-15, Delta S = -5.1419e-08 (per sweep)
# max trunc_err = 5.1075e-23, max E_trunc = 1.7764e-15
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.32323232323232326
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=1.1597349129177554e-21
# INFO    : checkpoint after sweep 1
# energy=-9.3159111555704790, max S=0.6936419566454310, age=10, norm_err=1.6e-01
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 6.6914e-01 (per sweep)
# max trunc_err = 2.3195e-20, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 11, 12, 11, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.3159111555704577, max S=0.6936432962451662, age=10, norm_err=5.0e-14
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = 2.1316e-14, Delta S = 1.1542e-02 (per sweep)
# max trunc_err = 2.0919e-20, max E_trunc = 1.5987e-14
# chi: [2, 4, 8, 16, 15, 13, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.3159111555704612, max S=0.6936432962451666, age=10, norm_err=3.2e-14
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = -3.5527e-15, Delta S = -5.8571e-08 (per sweep)
# max trunc_err = 2.6121e-20, max E_trunc = 7.1054e-15
# chi: [2, 4, 8, 13, 15, 14, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.3159111555704559, max S=0.6936432962451643, age=10, norm_err=6.1e-15
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 5.3291e-15, Delta S = -5.8572e-08 (per sweep)
# max trunc_err = 1.7360e-22, max E_trunc = 7.1054e-15
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.3434343434343435
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-9.3570129603657719, max S=0.6937591212954651, age=10, norm_err=1.6e-01
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 6.6649e-01 (per sweep)
# max trunc_err = 7.4334e-21, max E_trunc = 6.2172e-15
# chi: [2, 4, 8, 14, 13, 13, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.3570129603657737, max S=0.6937596804131158, age=10, norm_err=2.4e-13
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = -1.7764e-15, Delta S = 1.2426e-02 (per sweep)
# max trunc_err = 1.4995e-20, max E_trunc = 8.8818e-15
# chi: [2, 4, 8, 13, 18, 14, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.3570129603657826, max S=0.6937596804131096, age=10, norm_err=6.0e-14
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = -8.8818e-15, Delta S = -6.6206e-08 (per sweep)
# max trunc_err = 2.1189e-20, max E_trunc = 5.3291e-15
# chi: [2, 4, 8, 15, 16, 15, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.3570129603657666, max S=0.6937596804131068, age=10, norm_err=8.3e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 1.5987e-14, Delta S = -6.6207e-08 (per sweep)
# max trunc_err = 5.2673e-22, max E_trunc = 8.8818e-15
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.36363636363636365
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 1
# energy=-9.4007077296708736, max S=0.6938854113262707, age=10, norm_err=1.6e-01
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = nan, Delta S = 6.6373e-01 (per sweep)
# max trunc_err = 8.3585e-21, max E_trunc = 1.2434e-14
# chi: [2, 4, 8, 8, 10, 12, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.4007077296708790, max S=0.6938877731445863, age=10, norm_err=2.1e-13
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -5.3291e-15, Delta S = 1.3261e-02 (per sweep)
# max trunc_err = 1.0520e-20, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 13, 17, 15, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.4007077296708754, max S=0.6938877731445887, age=10, norm_err=1.6e-14
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = 3.5527e-15, Delta S = -7.4329e-08 (per sweep)
# max trunc_err = 1.9967e-20, max E_trunc = 1.0658e-14
# chi: [2, 4, 8, 14, 16, 14, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.4007077296708683, max S=0.6938877731445832, age=10, norm_err=1.4e-14
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = 7.1054e-15, Delta S = -7.4330e-08 (per sweep)
# max trunc_err = 1.5456e-21, max E_trunc = 8.8818e-15
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.38383838383838387
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 1
# energy=-9.4470172010050675, max S=0.6940183231778743, age=10, norm_err=1.6e-01
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 6.6086e-01 (per sweep)
# max trunc_err = 8.3742e-21, max E_trunc = 8.8818e-15
# chi: [2, 4, 8, 10, 13, 12, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-9.4470172010050728, max S=0.6940228708138243, age=10, norm_err=1.7e-14
# Current memory usage 186.1MB, wall time: 0.8s
# Delta E = -5.3291e-15, Delta S = 1.4038e-02 (per sweep)
# max trunc_err = 1.4016e-20, max E_trunc = 1.2434e-14
# chi: [2, 4, 8, 13, 17, 14, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-9.4470172010050710, max S=0.6940228708138199, age=10, norm_err=1.6e-14
# Current memory usage 186.1MB, wall time: 0.8s
# Delta E = 1.7764e-15, Delta S = -8.2946e-08 (per sweep)
# max trunc_err = 9.5010e-21, max E_trunc = 5.3291e-15
# chi: [2, 4, 8, 16, 16, 14, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-9.4470172010050693, max S=0.6940228708138179, age=10, norm_err=1.8e-14
# Current memory usage 186.1MB, wall time: 0.3s
# ...
# energy=-20.0028434563868807, max S=0.0996161374417136, age=10, norm_err=8.9e-13
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = 1.0658e-14, Delta S = 7.0836e-04 (per sweep)
# max trunc_err = 1.5097e-20, max E_trunc = 3.9080e-14
# chi: [2, 4, 8, 12, 15, 13, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-20.0028434563869020, max S=0.0996161374417128, age=10, norm_err=1.6e-14
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = -2.1316e-14, Delta S = -1.0640e-06 (per sweep)
# max trunc_err = 1.1069e-20, max E_trunc = 1.4211e-14
# chi: [2, 4, 8, 12, 17, 13, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-20.0028434563869091, max S=0.0996161374417135, age=10, norm_err=2.6e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = -7.1054e-15, Delta S = -1.0641e-06 (per sweep)
# max trunc_err = 1.0722e-21, max E_trunc = 2.8422e-14
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1.8989898989898992
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.709566042870197e-22
# INFO    : checkpoint after sweep 1
# energy=-20.1915550741442864, max S=0.0976647677290288, age=10, norm_err=2.1e-03
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 9.5010e-02 (per sweep)
# max trunc_err = 1.1419e-20, max E_trunc = 1.7764e-14
# chi: [2, 4, 8, 10, 10, 11, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-20.1915550741442615, max S=0.0976721388181798, age=10, norm_err=7.6e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = 2.4869e-14, Delta S = 6.8179e-04 (per sweep)
# max trunc_err = 1.0600e-20, max E_trunc = 3.1974e-14
# chi: [2, 4, 8, 13, 17, 13, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-20.1915550741442473, max S=0.0976721388181766, age=10, norm_err=1.5e-14
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = 1.4211e-14, Delta S = -1.0710e-06 (per sweep)
# max trunc_err = 1.7094e-20, max E_trunc = 2.1316e-14
# chi: [2, 4, 8, 12, 16, 14, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-20.1915550741442864, max S=0.0976721388181772, age=10, norm_err=1.9e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = -3.9080e-14, Delta S = -1.0710e-06 (per sweep)
# max trunc_err = 8.5000e-22, max E_trunc = 2.1316e-14
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1.9191919191919193
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-20.3805596289640114, max S=0.0957838336383005, age=10, norm_err=2.0e-03
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 9.3242e-02 (per sweep)
# max trunc_err = 4.1091e-21, max E_trunc = 2.4869e-14
# chi: [2, 4, 8, 11, 9, 11, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-20.3805596289640967, max S=0.0957905202384873, age=10, norm_err=6.5e-13
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = -8.5265e-14, Delta S = 6.5617e-04 (per sweep)
# max trunc_err = 1.8052e-20, max E_trunc = 2.4869e-14
# chi: [2, 4, 8, 12, 16, 13, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-20.3805596289640789, max S=0.0957905202384989, age=10, norm_err=6.7e-13
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = 1.7764e-14, Delta S = -1.0779e-06 (per sweep)
# max trunc_err = 1.6670e-20, max E_trunc = 2.1316e-14
# chi: [2, 4, 8, 13, 15, 13, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-20.3805596289640327, max S=0.0957905202384877, age=10, norm_err=5.6e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = 4.6185e-14, Delta S = -1.0779e-06 (per sweep)
# max trunc_err = 6.9142e-22, max E_trunc = 2.8422e-14
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1.9393939393939394
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 1
# energy=-20.5698473983992436, max S=0.0939622953238298, age=10, norm_err=2.0e-03
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = nan, Delta S = 9.1528e-02 (per sweep)
# max trunc_err = 4.0155e-21, max E_trunc = 3.9080e-14
# chi: [2, 4, 8, 10, 9, 11, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-20.5698473983993004, max S=0.0939684190854458, age=10, norm_err=3.7e-13
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = -5.6843e-14, Delta S = 6.3164e-04 (per sweep)
# max trunc_err = 1.0227e-20, max E_trunc = 3.1974e-14
# chi: [2, 4, 8, 12, 17, 13, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-20.5698473983992720, max S=0.0939684190854438, age=10, norm_err=6.0e-13
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 2.8422e-14, Delta S = -1.0846e-06 (per sweep)
# max trunc_err = 1.8550e-20, max E_trunc = 2.4869e-14
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-20.5698473983993111, max S=0.0939684190854435, age=10, norm_err=6.0e-15
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -3.9080e-14, Delta S = -1.0847e-06 (per sweep)
# max trunc_err = 5.6290e-22, max E_trunc = 2.4869e-14
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1.9595959595959598
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-20.7594090926171688, max S=0.0921976132819242, age=10, norm_err=1.9e-03
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 8.9865e-02 (per sweep)
# max trunc_err = 1.0081e-20, max E_trunc = 2.1316e-14
# chi: [2, 4, 8, 12, 11, 9, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-20.7594090926171724, max S=0.0922031459907858, age=10, norm_err=4.2e-14
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = -3.5527e-15, Delta S = 6.0848e-04 (per sweep)
# max trunc_err = 1.0631e-20, max E_trunc = 3.5527e-14
# chi: [2, 4, 8, 13, 16, 14, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-20.7594090926171617, max S=0.0922031459908003, age=10, norm_err=6.0e-13
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 1.0658e-14, Delta S = -1.0913e-06 (per sweep)
# max trunc_err = 1.0641e-20, max E_trunc = 3.1974e-14
# chi: [2, 4, 8, 14, 16, 14, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-20.7594090926171901, max S=0.0922031459907849, age=10, norm_err=4.8e-15
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -2.8422e-14, Delta S = -1.0914e-06 (per sweep)
# max trunc_err = 4.3427e-22, max E_trunc = 1.7764e-14
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1.97979797979798
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : checkpoint after sweep 1
# energy=-20.9492358302090587, max S=0.0904910265216214, age=10, norm_err=1.8e-03
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 8.8250e-02 (per sweep)
# max trunc_err = 6.6955e-21, max E_trunc = 1.7764e-14
# chi: [2, 4, 8, 9, 11, 12, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-20.9492358302090942, max S=0.0904921717920510, age=10, norm_err=2.6e-13
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -3.5527e-14, Delta S = 5.8682e-04 (per sweep)
# max trunc_err = 1.5399e-20, max E_trunc = 3.1974e-14
# chi: [2, 4, 8, 13, 15, 11, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-20.9492358302091404, max S=0.0904921717920468, age=10, norm_err=6.8e-14
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = -4.6185e-14, Delta S = -1.0980e-06 (per sweep)
# max trunc_err = 1.4634e-20, max E_trunc = 1.4211e-14
# chi: [2, 4, 8, 13, 15, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-20.9492358302091191, max S=0.0904921717920485, age=10, norm_err=5.2e-15
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 2.1316e-14, Delta S = -1.0980e-06 (per sweep)
# max trunc_err = 8.5908e-21, max E_trunc = 7.4607e-14
# chi: [2, 4, 8, 12, 14, 12, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='finite'
# INFO    : TFIChain: reading 'L'=10
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=2.0
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : checkpoint after sweep 1
# energy=-21.1393191156311460, max S=0.0888285167989468, age=10, norm_err=1.7e-03
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 8.6682e-02 (per sweep)
# max trunc_err = 1.9572e-20, max E_trunc = 4.2633e-14
# chi: [2, 4, 8, 12, 10, 10, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-21.1393191156311921, max S=0.0888331156552143, age=10, norm_err=1.1e-13
# Current memory usage 186.1MB, wall time: 0.9s
# Delta E = -4.6185e-14, Delta S = 5.6589e-04 (per sweep)
# max trunc_err = 1.0214e-20, max E_trunc = 2.4869e-14
# chi: [2, 4, 8, 12, 16, 12, 8, 4, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-21.1393191156312064, max S=0.0888331156552076, age=10, norm_err=6.1e-15
# Current memory usage 186.1MB, wall time: 2.2s
# Delta E = -1.4211e-14, Delta S = -1.1045e-06 (per sweep)
# max trunc_err = 9.5729e-21, max E_trunc = 4.6185e-14
# chi: [2, 4, 8, 13, 14, 14, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-21.1393191156311744, max S=0.0888331156552073, age=10, norm_err=2.9e-15
# Current memory usage 186.1MB, wall time: 0.9s
# Delta E = 3.1974e-14, Delta S = -1.1045e-06 (per sweep)
# max trunc_err = 8.7135e-21, max E_trunc = 2.8422e-14
# chi: [2, 4, 8, 11, 14, 11, 8, 4, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 4 sweeps, max chi=14

# %%
plt.figure(figsize=(6, 6))
plt.plot(g_arr, Sz_arr)
plt.title("10 Sites")
plt.xlabel("g")
plt.ylabel("<x>")
plt.show()

# %%
g_arr = np.linspace(0, 2, 100)

def sim(g):
    N = 2
    model = TFIChain({"L": N, "J": 1, "g": g, "bc_MPS": "infinite"})
    sites = model.lat.mps_sites()
    psi = MPS.from_product_state(sites, ['up'] * N, "infinite")
    dmrg_params = {"trunc_params": {"chi_max": 100, "svd_min": 1.e-10}, "mixer": True}
    info = dmrg.run(psi, model, dmrg_params)
    return np.mean(psi.expectation_value("Sz"))

Sz_arr = np.array([sim(g) for g in g_arr])
# Out:
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.0
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-0.9999999999999858, max S=0.6931471805599576, age=128, norm_err=5.3e-16
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 6.9315e-02 (per sweep)
# max trunc_err = 3.9093e-21, max E_trunc = 2.8422e-14
# chi: [2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-0.9999999999999964, max S=0.6931471805599474, age=248, norm_err=3.2e-16
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -1.0658e-15, Delta S = -9.6589e-16 (per sweep)
# max trunc_err = 8.7563e-22, max E_trunc = 5.6843e-14
# chi: [2, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-0.9999999999999858, max S=0.6931471805599452, age=368, norm_err=4.5e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 1.0658e-15, Delta S = -1.5543e-16 (per sweep)
# max trunc_err = 1.5661e-28, max E_trunc = 5.6843e-14
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.020202020202020204
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0001020330079022, max S=0.6931471976655852, age=128, norm_err=3.0e-14
# Current memory usage 186.1MB, wall time: 1.9s
# Delta E = nan, Delta S = 6.9315e-02 (per sweep)
# max trunc_err = 1.3645e-23, max E_trunc = 5.6843e-14
# chi: [6, 9]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0001020330079022, max S=0.6931471953162653, age=248, norm_err=1.8e-15
# Current memory usage 186.1MB, wall time: 1.9s
# Delta E = 0.0000e+00, Delta S = -2.3493e-10 (per sweep)
# max trunc_err = 1.1392e-23, max E_trunc = 5.6843e-14
# chi: [7, 8]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0001020330079342, max S=0.6931471949791861, age=368, norm_err=4.2e-16
# Current memory usage 186.1MB, wall time: 1.0s
# Delta E = -3.1974e-15, Delta S = -3.3708e-11 (per sweep)
# max trunc_err = 5.5475e-28, max E_trunc = 2.2737e-13
# chi: [6, 6]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=6
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.04040404040404041
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=7.6470424025586e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0004081632781112, max S=0.6931473919966294, age=128, norm_err=1.8e-13
# Current memory usage 186.1MB, wall time: 2.0s
# Delta E = nan, Delta S = 6.9315e-02 (per sweep)
# max trunc_err = 1.5294e-20, max E_trunc = 1.4211e-14
# chi: [6, 6]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0004081632780562, max S=0.6931473837999964, age=248, norm_err=7.8e-14
# Current memory usage 186.1MB, wall time: 2.0s
# Delta E = 5.5067e-15, Delta S = -8.1966e-10 (per sweep)
# max trunc_err = 1.4268e-20, max E_trunc = 0.0000e+00
# chi: [7, 7]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0004081632781023, max S=0.6931473826274992, age=368, norm_err=8.2e-16
# Current memory usage 186.1MB, wall time: 0.9s
# Delta E = -4.6185e-15, Delta S = -1.1725e-10 (per sweep)
# max trunc_err = 2.2653e-24, max E_trunc = 1.7053e-13
# chi: [6, 6]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=6
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.06060606060606061
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0009184846460144, max S=0.6931481389683124, age=128, norm_err=1.3e-15
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 6.9315e-02 (per sweep)
# max trunc_err = 4.8142e-20, max E_trunc = 7.1054e-14
# chi: [9, 8]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0009184846460499, max S=0.6931481221302612, age=248, norm_err=4.5e-15
# Current memory usage 186.1MB, wall time: 2.4s
# Delta E = -3.5527e-15, Delta S = -1.6838e-09 (per sweep)
# max trunc_err = 6.8611e-21, max E_trunc = 5.6843e-14
# chi: [8, 9]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0009184846460215, max S=0.6931481197231925, age=368, norm_err=1.0e-15
# Current memory usage 186.1MB, wall time: 1.1s
# Delta E = 2.8422e-15, Delta S = -2.4071e-10 (per sweep)
# max trunc_err = 2.9532e-22, max E_trunc = 5.6843e-14
# chi: [6, 6]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=6
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.08080808080808081
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0016331538244181, max S=0.6931499957978797, age=128, norm_err=4.8e-15
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 6.9315e-02 (per sweep)
# max trunc_err = 3.2527e-21, max E_trunc = 4.2633e-14
# chi: [11, 11]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0016331538244430, max S=0.6931499678871503, age=248, norm_err=1.4e-13
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = -2.4869e-15, Delta S = -2.7911e-09 (per sweep)
# max trunc_err = 8.0328e-21, max E_trunc = 5.6843e-14
# chi: [10, 10]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0016331538243008, max S=0.6931499638981324, age=368, norm_err=6.4e-16
# Current memory usage 186.1MB, wall time: 1.4s
# Delta E = 1.4211e-14, Delta S = -3.9890e-10 (per sweep)
# max trunc_err = 9.3869e-21, max E_trunc = 1.7053e-13
# chi: [6, 6]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=6
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.10101010101010102
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0025523908864784, max S=0.6931536798269278, age=128, norm_err=1.8e-14
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = nan, Delta S = 6.9315e-02 (per sweep)
# max trunc_err = 4.9298e-22, max E_trunc = 5.6843e-14
# chi: [12, 11]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0025523908864464, max S=0.6931536386594783, age=248, norm_err=3.0e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = 3.1974e-15, Delta S = -4.1167e-09 (per sweep)
# max trunc_err = 6.1673e-21, max E_trunc = 8.5265e-14
# chi: [11, 11]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0025523908866987, max S=0.6931536327764597, age=368, norm_err=9.2e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -2.5224e-14, Delta S = -5.8830e-10 (per sweep)
# max trunc_err = 4.5330e-26, max E_trunc = 0.0000e+00
# chi: [10, 10]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.12121212121212122
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0036764799487656, max S=0.6931600571914970, age=128, norm_err=9.1e-16
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 6.9316e-02 (per sweep)
# max trunc_err = 1.0436e-21, max E_trunc = 1.4211e-14
# chi: [11, 11]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0036764799487052, max S=0.6931600007686560, age=248, norm_err=3.8e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 6.0396e-15, Delta S = -5.6423e-09 (per sweep)
# max trunc_err = 1.1853e-21, max E_trunc = 1.4211e-13
# chi: [10, 11]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0036764799487159, max S=0.6931599927060612, age=368, norm_err=3.1e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -1.0658e-15, Delta S = -8.0626e-10 (per sweep)
# max trunc_err = 8.2234e-25, max E_trunc = 1.1369e-13
# chi: [10, 10]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.14141414141414144
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0050057700595598, max S=0.6931701373342605, age=128, norm_err=2.1e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 6.9317e-02 (per sweep)
# max trunc_err = 2.9273e-21, max E_trunc = 8.5265e-14
# chi: [11, 11]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0050057700595474, max S=0.6931700638036032, age=248, norm_err=8.2e-16
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 1.2434e-15, Delta S = -7.3531e-09 (per sweep)
# max trunc_err = 1.1626e-20, max E_trunc = 1.1369e-13
# chi: [10, 11]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0050057700595403, max S=0.6931700532968081, age=368, norm_err=5.1e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 7.1054e-16, Delta S = -1.0507e-09 (per sweep)
# max trunc_err = 9.8512e-24, max E_trunc = 0.0000e+00
# chi: [10, 10]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.16161616161616163
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0065406763012916, max S=0.6931850716475566, age=128, norm_err=5.8e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 6.9319e-02 (per sweep)
# max trunc_err = 1.5702e-20, max E_trunc = 2.8422e-14
# chi: [11, 10]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0065406763013414, max S=0.6931849792759109, age=248, norm_err=4.9e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -4.9738e-15, Delta S = -9.2372e-09 (per sweep)
# max trunc_err = 2.0778e-20, max E_trunc = 2.8422e-13
# chi: [10, 10]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0065406763013485, max S=0.6931849660773450, age=368, norm_err=3.4e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -7.1054e-16, Delta S = -1.3199e-09 (per sweep)
# max trunc_err = 8.5231e-23, max E_trunc = 5.6843e-14
# chi: [10, 10]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.18181818181818182
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0082816811171487, max S=0.6932061554348032, age=128, norm_err=1.9e-14
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 6.9321e-02 (per sweep)
# max trunc_err = 1.8612e-20, max E_trunc = 7.1054e-14
# chi: [12, 11]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0082816811171789, max S=0.6932060425883150, age=248, norm_err=3.2e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -3.0198e-15, Delta S = -1.1285e-08 (per sweep)
# max trunc_err = 1.9670e-24, max E_trunc = 3.1264e-13
# chi: [11, 12]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0082816811171611, max S=0.6932060264646032, age=368, norm_err=4.6e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 1.7764e-15, Delta S = -1.6124e-09 (per sweep)
# max trunc_err = 5.7492e-22, max E_trunc = 1.1369e-13
# chi: [10, 10]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.20202020202020204
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0102293358742003, max S=0.6932348327911249, age=128, norm_err=1.7e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 6.9323e-02 (per sweep)
# max trunc_err = 2.0117e-22, max E_trunc = 5.6843e-14
# chi: [14, 16]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0102293358742287, max S=0.6932346979197209, age=248, norm_err=1.8e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = -2.8422e-15, Delta S = -1.3487e-08 (per sweep)
# max trunc_err = 3.8408e-23, max E_trunc = 8.5265e-14
# chi: [16, 16]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0102293358743069, max S=0.6932346786494235, age=368, norm_err=9.3e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -7.8160e-15, Delta S = -1.9270e-09 (per sweep)
# max trunc_err = 3.1887e-21, max E_trunc = 0.0000e+00
# chi: [10, 10]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.22222222222222224
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0123842626793067, max S=0.6932727042376003, age=128, norm_err=7.3e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 6.9327e-02 (per sweep)
# max trunc_err = 8.3912e-23, max E_trunc = 2.8422e-14
# chi: [17, 17]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0123842626793298, max S=0.6932725458627741, age=248, norm_err=1.9e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = -2.3093e-15, Delta S = -1.5837e-08 (per sweep)
# max trunc_err = 6.1708e-23, max E_trunc = 2.2737e-13
# chi: [15, 16]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0123842626794755, max S=0.6932725232347267, age=368, norm_err=2.9e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -1.4566e-14, Delta S = -2.2628e-09 (per sweep)
# max trunc_err = 1.5105e-20, max E_trunc = -1.7053e-13
# chi: [10, 10]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=10
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.24242424242424243
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0147471564646526, max S=0.6933215371031214, age=128, norm_err=6.9e-15
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 6.9332e-02 (per sweep)
# max trunc_err = 3.6462e-22, max E_trunc = 8.5265e-14
# chi: [16, 15]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0147471564646366, max S=0.6933213538076752, age=248, norm_err=5.0e-15
# Current memory usage 186.1MB, wall time: 0.3s
# Delta E = 1.5987e-15, Delta S = -1.8330e-08 (per sweep)
# max trunc_err = 2.2611e-22, max E_trunc = -8.5265e-14
# chi: [16, 16]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0147471564646722, max S=0.6933213276194266, age=368, norm_err=5.8e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -3.5527e-15, Delta S = -2.6188e-09 (per sweep)
# max trunc_err = 1.4910e-24, max E_trunc = 1.1369e-13
# chi: [14, 14]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.26262626262626265
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0173187873654612, max S=0.6933832787677984, age=128, norm_err=9.1e-15
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 6.9338e-02 (per sweep)
# max trunc_err = 1.7683e-21, max E_trunc = 7.1054e-14
# chi: [18, 15]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0173187873654079, max S=0.6933830691872556, age=248, norm_err=4.9e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 5.3291e-15, Delta S = -2.0958e-08 (per sweep)
# max trunc_err = 3.2965e-21, max E_trunc = -2.8422e-14
# chi: [16, 16]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0173187873652694, max S=0.6933830392438827, age=368, norm_err=1.2e-15
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 1.3856e-14, Delta S = -2.9943e-09 (per sweep)
# max trunc_err = 7.7548e-24, max E_trunc = 3.4106e-13
# chi: [14, 14]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.2828282828282829
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0201000034139156, max S=0.6934600729937568, age=128, norm_err=1.7e-14
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 6.9346e-02 (per sweep)
# max trunc_err = 7.6160e-21, max E_trunc = 1.4211e-14
# chi: [16, 15]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0201000034139227, max S=0.6934598358089901, age=248, norm_err=2.8e-14
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -7.1054e-16, Delta S = -2.3718e-08 (per sweep)
# max trunc_err = 1.0050e-20, max E_trunc = 1.7053e-13
# chi: [15, 16]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0201000034138517, max S=0.6934598019220464, age=368, norm_err=5.2e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 7.1054e-15, Delta S = -3.3887e-09 (per sweep)
# max trunc_err = 3.6017e-23, max E_trunc = 1.7053e-13
# chi: [14, 14]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.30303030303030304
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0230917335800775, max S=0.6935542796770165, age=128, norm_err=2.4e-14
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 6.9355e-02 (per sweep)
# max trunc_err = 2.1433e-20, max E_trunc = 4.2633e-14
# chi: [16, 16]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0230917335801593, max S=0.6935540136078131, age=248, norm_err=1.8e-14
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -8.1712e-15, Delta S = -2.6607e-08 (per sweep)
# max trunc_err = 3.1289e-20, max E_trunc = 5.6843e-14
# chi: [17, 17]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0230917335797329, max S=0.6935539755944006, age=368, norm_err=1.3e-15
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 4.2633e-14, Delta S = -3.8013e-09 (per sweep)
# max trunc_err = 1.5174e-22, max E_trunc = 5.6843e-13
# chi: [14, 14]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.32323232323232326
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0262949911928576, max S=0.6936684984720344, age=128, norm_err=2.2e-14
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 6.9367e-02 (per sweep)
# max trunc_err = 4.9414e-21, max E_trunc = 7.1054e-14
# chi: [15, 16]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0262949911927919, max S=0.6936682022713602, age=248, norm_err=2.0e-14
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 6.5725e-15, Delta S = -2.9620e-08 (per sweep)
# max trunc_err = 1.5817e-21, max E_trunc = 8.5265e-14
# chi: [15, 16]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0262949911927990, max S=0.6936681599533268, age=368, norm_err=4.6e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -7.1054e-16, Delta S = -4.2318e-09 (per sweep)
# max trunc_err = 5.8755e-22, max E_trunc = 3.4106e-13
# chi: [14, 14]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.3434343434343435
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0297108777820103, max S=0.6938055968749749, age=128, norm_err=4.4e-15
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = nan, Delta S = 6.9381e-02 (per sweep)
# max trunc_err = 1.3062e-20, max E_trunc = 8.5265e-14
# chi: [14, 16]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0297108777819624, max S=0.6938052693238671, age=248, norm_err=8.5e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 4.7962e-15, Delta S = -3.2755e-08 (per sweep)
# max trunc_err = 4.6327e-21, max E_trunc = 3.1264e-13
# chi: [16, 17]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0297108777821364, max S=0.6938052225270538, age=368, norm_err=9.7e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -1.7408e-14, Delta S = -4.6797e-09 (per sweep)
# max trunc_err = 2.1138e-21, max E_trunc = 0.0000e+00
# chi: [14, 14]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.36363636363636365
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0333405873880945, max S=0.6939687435119555, age=128, norm_err=1.9e-15
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 6.9397e-02 (per sweep)
# max trunc_err = 3.3478e-20, max E_trunc = 1.4211e-14
# chi: [20, 19]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0333405873880253, max S=0.6939683834147090, age=248, norm_err=3.1e-15
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = 6.9278e-15, Delta S = -3.6010e-08 (per sweep)
# max trunc_err = 1.2653e-20, max E_trunc = 1.9895e-13
# chi: [15, 16]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0333405873881318, max S=0.6939683319683069, age=368, norm_err=7.5e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -1.0658e-14, Delta S = -5.1446e-09 (per sweep)
# max trunc_err = 7.1307e-21, max E_trunc = -1.1369e-13
# chi: [14, 14]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.38383838383838387
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0371854113959635, max S=0.6941614475735091, age=128, norm_err=1.9e-15
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 6.9416e-02 (per sweep)
# max trunc_err = 4.5945e-20, max E_trunc = 5.6843e-14
# chi: [18, 17]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0371854113959778, max S=0.6941610537533838, age=248, norm_err=1.2e-14
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = -1.4211e-15, Delta S = -3.9382e-08 (per sweep)
# max trunc_err = 3.4456e-20, max E_trunc = 2.2737e-13
# chi: [16, 16]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0371854113958960, max S=0.6941609974892842, age=368, norm_err=3.4e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 8.1712e-15, Delta S = -5.6264e-09 (per sweep)
# max trunc_err = 2.2728e-20, max E_trunc = 0.0000e+00
# chi: [14, 14]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=14
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.4040404040404041
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0412467439557371, max S=0.6943876055812154, age=128, norm_err=5.2e-15
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = nan, Delta S = 6.9439e-02 (per sweep)
# max trunc_err = 8.4766e-21, max E_trunc = 4.2633e-14
# chi: [20, 16]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0412467439557105, max S=0.6943871768761624, age=248, norm_err=2.0e-15
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = 2.6645e-15, Delta S = -4.2870e-08 (per sweep)
# max trunc_err = 1.8648e-21, max E_trunc = 1.4211e-13
# chi: [21, 21]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0412467439559876, max S=0.6943871156283102, age=368, norm_err=1.0e-15
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -2.7711e-14, Delta S = -6.1248e-09 (per sweep)
# max trunc_err = 1.0461e-23, max E_trunc = -5.6843e-14
# chi: [20, 20]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=20
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.42424242424242425
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0455260880691633, max S=0.6946515569791744, age=128, norm_err=2.3e-15
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 6.9465e-02 (per sweep)
# max trunc_err = 1.9472e-21, max E_trunc = 7.1054e-14
# chi: [22, 20]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0455260880690638, max S=0.6946510922378473, age=248, norm_err=3.8e-15
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = 9.9476e-15, Delta S = -4.6474e-08 (per sweep)
# max trunc_err = 3.8917e-21, max E_trunc = 1.7053e-13
# chi: [23, 23]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0455260880691952, max S=0.6946510258418335, age=368, norm_err=5.5e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -1.3145e-14, Delta S = -6.6396e-09 (per sweep)
# max trunc_err = 3.7696e-23, max E_trunc = 1.7053e-13
# chi: [20, 20]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=20
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.4444444444444445
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0500250624302225, max S=0.6949581504393813, age=128, norm_err=7.0e-15
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 6.9496e-02 (per sweep)
# max trunc_err = 8.9166e-21, max E_trunc = 2.8422e-14
# chi: [20, 21]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.0500250624302225, max S=0.6949576485180303, age=248, norm_err=2.3e-15
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = 0.0000e+00, Delta S = -5.0192e-08 (per sweep)
# max trunc_err = 1.3678e-20, max E_trunc = 3.1264e-13
# chi: [22, 20]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.0500250624299952, max S=0.6949575768104012, age=368, norm_err=8.6e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 2.2737e-14, Delta S = -7.1708e-09 (per sweep)
# max trunc_err = 1.2958e-22, max E_trunc = 4.5475e-13
# chi: [20, 20]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=20
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.4646464646464647
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.0547454091297972, max S=0.6953128232836924, age=128, norm_err=9.3e-15
# Current memory usage 186.1MB, wall time: 0.7s
# ...
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1.9957298974033044, max S=0.1016546604666160, age=128, norm_err=1.3e-15
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = nan, Delta S = 1.0165e-02 (per sweep)
# max trunc_err = 2.3950e-20, max E_trunc = 1.1369e-13
# chi: [19, 18]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1.9957298974032867, max S=0.1016504378254622, age=248, norm_err=9.6e-16
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = 1.7764e-15, Delta S = -4.2226e-07 (per sweep)
# max trunc_err = 2.4012e-20, max E_trunc = -5.6843e-14
# chi: [18, 16]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1.9957298974028674, max S=0.1016498345749194, age=368, norm_err=5.7e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 4.1922e-14, Delta S = -6.0325e-08 (per sweep)
# max trunc_err = 2.3646e-20, max E_trunc = 9.0949e-13
# chi: [15, 15]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=15
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1.878787878787879
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-2.0143968507088168, max S=0.0996422326455502, age=128, norm_err=1.6e-15
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 9.9642e-03 (per sweep)
# max trunc_err = 2.7636e-20, max E_trunc = 3.4106e-13
# chi: [18, 18]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-2.0143968507088843, max S=0.0996379826083941, age=248, norm_err=1.4e-15
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = -6.7502e-15, Delta S = -4.2500e-07 (per sweep)
# max trunc_err = 1.8602e-20, max E_trunc = 2.8422e-13
# chi: [16, 18]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-2.0143968507088488, max S=0.0996373754400896, age=368, norm_err=2.5e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 3.5527e-15, Delta S = -6.0717e-08 (per sweep)
# max trunc_err = 1.7435e-20, max E_trunc = 2.2737e-13
# chi: [15, 15]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=15
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1.8989898989898992
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-2.0330985810750555, max S=0.0976956433187662, age=128, norm_err=1.5e-15
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = nan, Delta S = 9.7696e-03 (per sweep)
# max trunc_err = 2.1684e-20, max E_trunc = 1.1369e-13
# chi: [17, 18]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-2.0330985810752580, max S=0.0976913662395924, age=248, norm_err=7.7e-16
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = -2.0250e-14, Delta S = -4.2771e-07 (per sweep)
# max trunc_err = 2.3819e-20, max E_trunc = 1.1369e-13
# chi: [17, 17]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-2.0330985810750519, max S=0.0976907552086079, age=368, norm_err=1.2e-15
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 2.0606e-14, Delta S = -6.1103e-08 (per sweep)
# max trunc_err = 1.2026e-20, max E_trunc = 9.0949e-13
# chi: [15, 15]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=15
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1.9191919191919193
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-2.0518338895744179, max S=0.0958117831050318, age=128, norm_err=1.7e-15
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 9.5812e-03 (per sweep)
# max trunc_err = 1.7414e-20, max E_trunc = 1.1369e-13
# chi: [19, 17]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-2.0518338895744606, max S=0.0958074793535605, age=248, norm_err=1.5e-15
# Current memory usage 186.1MB, wall time: 0.5s
# Delta E = -4.2633e-15, Delta S = -4.3038e-07 (per sweep)
# max trunc_err = 2.7018e-20, max E_trunc = 4.5475e-13
# chi: [17, 16]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-2.0518338895742687, max S=0.0958068645132264, age=368, norm_err=4.0e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 1.9185e-14, Delta S = -6.1484e-08 (per sweep)
# max trunc_err = 8.9935e-21, max E_trunc = 4.5475e-13
# chi: [15, 15]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=15
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1.9393939393939394
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-2.0706016333388817, max S=0.0939877393749150, age=128, norm_err=1.4e-15
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 9.3988e-03 (per sweep)
# max trunc_err = 2.8292e-20, max E_trunc = 1.1369e-13
# chi: [17, 18]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-2.0706016333388888, max S=0.0939834093217903, age=248, norm_err=1.3e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -7.1054e-16, Delta S = -4.3301e-07 (per sweep)
# max trunc_err = 2.0697e-20, max E_trunc = 3.9790e-13
# chi: [18, 18]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-2.0706016333387680, max S=0.0939827907238320, age=368, norm_err=7.8e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 1.2079e-14, Delta S = -6.1860e-08 (per sweep)
# max trunc_err = 6.7240e-21, max E_trunc = 7.9581e-13
# chi: [15, 15]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=15
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1.9595959595959598
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-2.0894007222182402, max S=0.0922207804056297, age=128, norm_err=1.6e-15
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 9.2221e-03 (per sweep)
# max trunc_err = 2.1033e-20, max E_trunc = 2.2737e-13
# chi: [18, 16]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-2.0894007222181443, max S=0.0922164244069925, age=248, norm_err=1.5e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 9.5923e-15, Delta S = -4.3560e-07 (per sweep)
# max trunc_err = 1.7717e-20, max E_trunc = 2.8422e-13
# chi: [18, 16]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-2.0894007222184854, max S=0.0922158021016795, age=368, norm_err=1.1e-15
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = -3.4106e-14, Delta S = -6.2231e-08 (per sweep)
# max trunc_err = 5.0416e-21, max E_trunc = -1.1369e-13
# chi: [15, 15]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=15
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1.97979797979798
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-2.1082301156823817, max S=0.0905083410798551, age=128, norm_err=1.1e-14
# Current memory usage 186.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 9.0508e-03 (per sweep)
# max trunc_err = 2.5839e-20, max E_trunc = 3.6948e-13
# chi: [16, 17]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-2.1082301156822965, max S=0.0905039594785573, age=248, norm_err=1.6e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = 8.5265e-15, Delta S = -4.3816e-07 (per sweep)
# max trunc_err = 1.3075e-20, max E_trunc = 5.1159e-13
# chi: [17, 16]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-2.1082301156817209, max S=0.0905033335147197, age=368, norm_err=1.1e-15
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 5.7554e-14, Delta S = -6.2596e-08 (per sweep)
# max trunc_err = 3.7985e-21, max E_trunc = 2.2737e-13
# chi: [15, 15]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=15
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=2.0
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-2.1270888199467066, max S=0.0888480099838844, age=128, norm_err=1.0e-14
# Current memory usage 186.1MB, wall time: 0.7s
# Delta E = nan, Delta S = 8.8848e-03 (per sweep)
# max trunc_err = 1.4595e-20, max E_trunc = 1.4211e-13
# chi: [17, 17]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-2.1270888199467279, max S=0.0888436031074240, age=248, norm_err=1.2e-15
# Current memory usage 186.1MB, wall time: 0.4s
# Delta E = -2.1316e-15, Delta S = -4.4069e-07 (per sweep)
# max trunc_err = 1.3383e-20, max E_trunc = 5.6843e-14
# chi: [19, 17]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-2.1270888199466782, max S=0.0888429735324126, age=368, norm_err=2.8e-16
# Current memory usage 186.1MB, wall time: 0.2s
# Delta E = 4.9738e-15, Delta S = -6.2958e-08 (per sweep)
# max trunc_err = 2.8332e-21, max E_trunc = 3.4106e-13
# chi: [15, 15]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=15

# %%
plt.figure(figsize=(6, 6))
plt.plot(g_arr, Sz_arr)
plt.title("Infinite Sites")
plt.xlabel("g")
plt.ylabel("<x>")
plt.show()

# %%
g_arr = np.linspace(0, 100000, 1000)

def sim(g):
    N = 2
    model = TFIChain({"L": N, "J": 1, "g": g, "bc_MPS": "infinite"})
    sites = model.lat.mps_sites()
    psi = MPS.from_product_state(sites, ['up'] * N, "infinite")
    dmrg_params = {"trunc_params": {"chi_max": 100, "svd_min": 1.e-10}, "mixer": True}
    info = dmrg.run(psi, model, dmrg_params)
    return np.mean(psi.expectation_value("Sz"))

Sz_arr = np.array([sim(g) for g in g_arr])
# Out:
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=0.0
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-0.9999999999999858, max S=0.6931471805599576, age=128, norm_err=5.3e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 6.9315e-02 (per sweep)
# max trunc_err = 3.9093e-21, max E_trunc = 2.8422e-14
# chi: [2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-0.9999999999999964, max S=0.6931471805599474, age=248, norm_err=3.2e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = -1.0658e-15, Delta S = -9.6589e-16 (per sweep)
# max trunc_err = 8.7563e-22, max E_trunc = 5.6843e-14
# chi: [2, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-0.9999999999999858, max S=0.6931471805599452, age=368, norm_err=4.5e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 1.0658e-15, Delta S = -1.5543e-16 (per sweep)
# max trunc_err = 1.5661e-28, max E_trunc = 5.6843e-14
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=100.10010010010011
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-100.1025976156777233, max S=0.0000958601934223, age=128, norm_err=5.3e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 9.5860e-06 (per sweep)
# max trunc_err = 4.7660e-21, max E_trunc = 1.0914e-11
# chi: [3, 4]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-100.1025976156734032, max S=0.0000828675164197, age=248, norm_err=4.4e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 4.3201e-13, Delta S = -1.2993e-06 (per sweep)
# max trunc_err = 4.9021e-21, max E_trunc = 2.1828e-11
# chi: [4, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-100.1025976156724937, max S=0.0000809968274115, age=368, norm_err=5.4e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 9.0949e-14, Delta S = -1.8707e-07 (per sweep)
# max trunc_err = 1.5140e-21, max E_trunc = 3.2742e-11
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=3
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=200.20020020020021
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-200.2014489521434371, max S=0.0000387205281210, age=128, norm_err=3.8e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 3.8721e-06 (per sweep)
# max trunc_err = 1.1248e-21, max E_trunc = 2.9104e-11
# chi: [3, 3]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-200.2014489521316136, max S=0.0000244920468107, age=248, norm_err=6.3e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 1.1823e-12, Delta S = -1.4228e-06 (per sweep)
# max trunc_err = 4.8695e-22, max E_trunc = 2.9104e-11
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-200.2014489521261567, max S=0.0000224103769782, age=368, norm_err=3.5e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 5.4570e-13, Delta S = -2.0817e-07 (per sweep)
# max trunc_err = 5.9134e-24, max E_trunc = 5.8208e-11
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=3
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=300.3003003003003
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-300.3011328008760756, max S=0.0000274966758645, age=128, norm_err=4.4e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 2.7497e-06 (per sweep)
# max trunc_err = 4.2750e-22, max E_trunc = 1.8190e-11
# chi: [3, 4]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-300.3011328008542478, max S=0.0000127216723042, age=248, norm_err=1.1e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 2.1828e-12, Delta S = -1.4775e-06 (per sweep)
# max trunc_err = 4.8067e-22, max E_trunc = 2.1828e-11
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-300.3011328008869896, max S=0.0000105221346286, age=368, norm_err=3.1e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -3.2742e-12, Delta S = -2.1995e-07 (per sweep)
# max trunc_err = 2.3076e-25, max E_trunc = 2.9104e-11
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=3
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=400.40040040040043
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-400.4010247756323224, max S=0.0000234840403628, age=128, norm_err=1.1e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 2.3484e-06 (per sweep)
# max trunc_err = 1.0811e-21, max E_trunc = 9.4587e-11
# chi: [4, 4]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-400.4010247756013996, max S=0.0000084210446007, age=248, norm_err=7.5e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 3.0923e-12, Delta S = -1.5063e-06 (per sweep)
# max trunc_err = 4.9347e-22, max E_trunc = 4.3656e-11
# chi: [4, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-400.4010247756232275, max S=0.0000061429920053, age=368, norm_err=5.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -2.1828e-12, Delta S = -2.2781e-07 (per sweep)
# max trunc_err = 2.3190e-26, max E_trunc = 0.0000e+00
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=3
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=500.50050050050055
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-500.5010000006213886, max S=0.0000216083427713, age=128, norm_err=3.4e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 2.1608e-06 (per sweep)
# max trunc_err = 2.7298e-22, max E_trunc = 2.1828e-11
# chi: [3, 5]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-500.5010000005931943, max S=0.0000063773961684, age=248, norm_err=2.2e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 2.8194e-12, Delta S = -1.5231e-06 (per sweep)
# max trunc_err = 3.3100e-23, max E_trunc = 1.0186e-10
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-500.5010000006368500, max S=0.0000040428602216, age=368, norm_err=2.2e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -4.3656e-12, Delta S = -2.3345e-07 (per sweep)
# max trunc_err = 3.9786e-27, max E_trunc = -2.9104e-11
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=3
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=600.6006006006006
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-600.6010168506418267, max S=0.0000205840140631, age=128, norm_err=1.0e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 2.0584e-06 (per sweep)
# max trunc_err = 1.0804e-22, max E_trunc = -1.4552e-11
# chi: [4, 4]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-600.6010168506254558, max S=0.0000052477267422, age=248, norm_err=5.4e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 1.6371e-12, Delta S = -1.5336e-06 (per sweep)
# max trunc_err = 4.2881e-23, max E_trunc = 1.3097e-10
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-600.6010168506545597, max S=0.0000028707200454, age=368, norm_err=7.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -2.9104e-12, Delta S = -2.3770e-07 (per sweep)
# max trunc_err = 5.2029e-21, max E_trunc = 0.0000e+00
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=700.7007007007007
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-700.7010574864507362, max S=0.0000199644165686, age=128, norm_err=7.0e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.9964e-06 (per sweep)
# max trunc_err = 7.1618e-22, max E_trunc = 1.2369e-10
# chi: [3, 3]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-700.7010574863270449, max S=0.0000045582562881, age=248, norm_err=1.3e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 1.2369e-11, Delta S = -1.5406e-06 (per sweep)
# max trunc_err = 2.3632e-22, max E_trunc = 2.3283e-10
# chi: [4, 4]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-700.7010574864398222, max S=0.0000021483453856, age=368, norm_err=4.6e-23
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -1.1278e-11, Delta S = -2.4099e-07 (per sweep)
# max trunc_err = 2.0629e-21, max E_trunc = 1.4552e-10
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=800.8008008008009
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-800.8011129882906971, max S=0.0000195614562839, age=128, norm_err=2.6e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.9561e-06 (per sweep)
# max trunc_err = 4.8034e-22, max E_trunc = 2.9104e-11
# chi: [5, 4]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-800.8011129882288515, max S=0.0000041068385191, age=248, norm_err=9.2e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 6.1846e-12, Delta S = -1.5455e-06 (per sweep)
# max trunc_err = 1.3802e-22, max E_trunc = 2.3283e-10
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-800.8011129882361274, max S=0.0000016708548475, age=368, norm_err=5.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -7.2760e-13, Delta S = -2.4360e-07 (per sweep)
# max trunc_err = 9.2599e-22, max E_trunc = 1.1642e-10
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=900.900900900901
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-900.9011784008871473, max S=0.0000192848072994, age=128, norm_err=7.3e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.9285e-06 (per sweep)
# max trunc_err = 4.2352e-22, max E_trunc = 1.0186e-10
# chi: [3, 4]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-900.9011784008544055, max S=0.0000037953422892, age=248, norm_err=4.4e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 3.2742e-12, Delta S = -1.5489e-06 (per sweep)
# max trunc_err = 2.8361e-22, max E_trunc = 5.8208e-11
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-900.9011784008762334, max S=0.0000013383215002, age=368, norm_err=6.3e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -2.1828e-12, Delta S = -2.4570e-07 (per sweep)
# max trunc_err = 4.5665e-22, max E_trunc = 2.9104e-10
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1001.0010010010011
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1001.0012507509727584, max S=0.0000190867288175, age=128, norm_err=3.1e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.9087e-06 (per sweep)
# max trunc_err = 5.9690e-21, max E_trunc = -1.4552e-11
# chi: [3, 4]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1001.0012507510364230, max S=0.0000035714385978, age=248, norm_err=1.1e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = -6.3665e-12, Delta S = -1.5515e-06 (per sweep)
# max trunc_err = 1.4392e-22, max E_trunc = 0.0000e+00
# chi: [3, 4]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1001.0012507510327850, max S=0.0000010971840542, age=368, norm_err=4.4e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 3.6380e-13, Delta S = -2.4743e-07 (per sweep)
# max trunc_err = 2.4268e-22, max E_trunc = 0.0000e+00
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1101.1011011011012
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1101.1013281464765896, max S=0.0000189400682741, age=128, norm_err=9.8e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.8940e-06 (per sweep)
# max trunc_err = 4.1022e-21, max E_trunc = 1.1642e-10
# chi: [3, 4]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1101.1013281464984175, max S=0.0000034051482522, age=248, norm_err=1.0e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = -2.1828e-12, Delta S = -1.5535e-06 (per sweep)
# max trunc_err = 1.8182e-22, max E_trunc = 2.3283e-10
# chi: [4, 4]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1101.1013281464038300, max S=0.0000009165900308, age=368, norm_err=2.2e-16
# Current memory usage 551.1MB, wall time: 0.3s
# Delta E = 9.4587e-12, Delta S = -2.4886e-07 (per sweep)
# max trunc_err = 1.3799e-22, max E_trunc = 2.9104e-10
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1201.2012012012012
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1201.2014093261059315, max S=0.0000188284606862, age=128, norm_err=1.1e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.8828e-06 (per sweep)
# max trunc_err = 8.0832e-22, max E_trunc = 1.4552e-10
# chi: [4, 3]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1201.2014093260586378, max S=0.0000032782946625, age=248, norm_err=5.0e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 4.7294e-12, Delta S = -1.5550e-06 (per sweep)
# max trunc_err = 3.7086e-22, max E_trunc = 8.7311e-11
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1201.2014093260950176, max S=0.0000007777281672, age=368, norm_err=2.2e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -3.6380e-12, Delta S = -2.5006e-07 (per sweep)
# max trunc_err = 8.1273e-23, max E_trunc = 5.8208e-11
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1301.3013013013015
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1301.3014934167294996, max S=0.0000187415674927, age=128, norm_err=6.7e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.8742e-06 (per sweep)
# max trunc_err = 8.6741e-23, max E_trunc = 1.4552e-10
# chi: [4, 3]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1301.3014934166858438, max S=0.0000031793383746, age=248, norm_err=8.0e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 4.3656e-12, Delta S = -1.5562e-06 (per sweep)
# max trunc_err = 1.8126e-23, max E_trunc = 2.9104e-10
# chi: [4, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1301.3014934167440515, max S=0.0000006685880794, age=368, norm_err=1.0e-15
# Current memory usage 551.1MB, wall time: 0.3s
# Delta E = -5.8208e-12, Delta S = -2.5108e-07 (per sweep)
# max trunc_err = 5.0278e-23, max E_trunc = 0.0000e+00
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1401.4014014014015
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1401.4015797942192876, max S=0.0000186725977081, age=128, norm_err=6.5e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.8673e-06 (per sweep)
# max trunc_err = 1.5485e-21, max E_trunc = 1.1642e-10
# chi: [4, 3]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1401.4015797941829078, max S=0.0000031006686587, age=248, norm_err=6.7e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 3.6380e-12, Delta S = -1.5572e-06 (per sweep)
# max trunc_err = 1.6659e-22, max E_trunc = -1.1642e-10
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1401.4015797940301127, max S=0.0000005812034679, age=368, norm_err=5.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 1.5280e-11, Delta S = -2.5195e-07 (per sweep)
# max trunc_err = 3.2230e-23, max E_trunc = -1.7462e-10
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1501.5015015015017
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1501.5016680013904988, max S=0.0000186169417260, age=128, norm_err=1.0e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.8617e-06 (per sweep)
# max trunc_err = 1.2015e-21, max E_trunc = 1.8917e-10
# chi: [4, 3]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1501.5016680012486177, max S=0.0000030371019433, age=248, norm_err=1.2e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 1.4188e-11, Delta S = -1.5580e-06 (per sweep)
# max trunc_err = 3.0542e-23, max E_trunc = 1.1642e-10
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1501.5016680013941368, max S=0.0000005101180609, age=368, norm_err=7.4e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -1.4552e-11, Delta S = -2.5270e-07 (per sweep)
# max trunc_err = 2.1406e-23, max E_trunc = 2.9104e-10
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1601.6016016016017
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1601.6017576953672688, max S=0.0000185713815872, age=128, norm_err=7.4e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.8571e-06 (per sweep)
# max trunc_err = 9.1901e-22, max E_trunc = -5.8208e-11
# chi: [4, 4]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1601.6017576952217496, max S=0.0000029850092960, age=248, norm_err=1.3e-15
# Current memory usage 551.1MB, wall time: 0.5s
# Delta E = 1.4552e-11, Delta S = -1.5586e-06 (per sweep)
# max trunc_err = 1.1532e-22, max E_trunc = 2.9104e-10
# chi: [3, 4]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1601.6017576952872332, max S=0.0000004514909383, age=368, norm_err=7.4e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -6.5484e-12, Delta S = -2.5335e-07 (per sweep)
# max trunc_err = 1.4535e-23, max E_trunc = 1.1642e-10
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1701.7017017017017
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1701.7018486135420972, max S=0.0000185336157595, age=128, norm_err=6.2e-16
# Current memory usage 551.1MB, wall time: 0.5s
# Delta E = nan, Delta S = 1.8534e-06 (per sweep)
# max trunc_err = 7.2462e-22, max E_trunc = 5.8208e-11
# chi: [4, 4]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1701.7018486134038540, max S=0.0000029417889356, age=248, norm_err=8.0e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 1.3824e-11, Delta S = -1.5592e-06 (per sweep)
# max trunc_err = 1.2737e-22, max E_trunc = 4.0745e-10
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1701.7018486136512365, max S=0.0000004025535329, age=368, norm_err=2.2e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -2.4738e-11, Delta S = -2.5392e-07 (per sweep)
# max trunc_err = 1.0109e-23, max E_trunc = -1.1642e-10
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1801.801801801802
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1801.8019405517989071, max S=0.0000185019629415, age=128, norm_err=6.7e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.8502e-06 (per sweep)
# max trunc_err = 5.8566e-22, max E_trunc = 2.3283e-10
# chi: [3, 3]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1801.8019405518862186, max S=0.0000029055363710, age=248, norm_err=1.1e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = -8.7311e-12, Delta S = -1.5596e-06 (per sweep)
# max trunc_err = 1.1627e-22, max E_trunc = 1.7462e-10
# chi: [4, 4]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1801.8019405518862186, max S=0.0000003612685844, age=368, norm_err=8.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 0.0000e+00, Delta S = -2.5443e-07 (per sweep)
# max trunc_err = 7.1352e-24, max E_trunc = 2.3283e-10
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=1901.901901901902
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-1901.9020333492226200, max S=0.0000184751718282, age=128, norm_err=7.0e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.8475e-06 (per sweep)
# max trunc_err = 4.6054e-22, max E_trunc = 8.7311e-11
# chi: [4, 3]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-1901.9020333493099315, max S=0.0000028748316461, age=248, norm_err=4.3e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = -8.7311e-12, Delta S = -1.5600e-06 (per sweep)
# max trunc_err = 1.1074e-22, max E_trunc = 7.5670e-10
# chi: [5, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-1901.9020333491644124, max S=0.0000003261094435, age=368, norm_err=3.1e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 1.4552e-11, Delta S = -2.5487e-07 (per sweep)
# max trunc_err = 5.1606e-24, max E_trunc = 3.4925e-10
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=2002.0020020020022
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-2002.0021268771924952, max S=0.0000184522955778, age=128, norm_err=2.0e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.8452e-06 (per sweep)
# max trunc_err = 4.2352e-22, max E_trunc = 0.0000e+00
# chi: [4, 4]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-2002.0021268770506140, max S=0.0000028485987086, age=248, norm_err=7.1e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 1.4188e-11, Delta S = -1.5604e-06 (per sweep)
# max trunc_err = 4.9383e-23, max E_trunc = 6.4028e-10
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-2002.0021268771088216, max S=0.0000002959134808, age=368, norm_err=9.9e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -5.8208e-12, Delta S = -2.5527e-07 (per sweep)
# max trunc_err = 3.8076e-24, max E_trunc = 3.4925e-10
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=2102.1021021021024
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-2102.1022210305563931, max S=0.0000184326070695, age=128, norm_err=5.4e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.8433e-06 (per sweep)
# max trunc_err = 3.0769e-22, max E_trunc = 3.7835e-10
# chi: [3, 3]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-2102.1022210303635802, max S=0.0000028260101147, age=248, norm_err=1.6e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 1.9281e-11, Delta S = -1.5607e-06 (per sweep)
# max trunc_err = 3.4742e-23, max E_trunc = 7.5670e-10
# chi: [4, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-2102.1022210304363398, max S=0.0000002697824245, age=368, norm_err=5.4e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -7.2760e-12, Delta S = -2.5562e-07 (per sweep)
# max trunc_err = 2.8295e-24, max E_trunc = 6.9849e-10
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=2202.2022022022024
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-2202.2023157248622738, max S=0.0000184155405223, age=128, norm_err=1.2e-15
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = nan, Delta S = 1.8416e-06 (per sweep)
# max trunc_err = 1.7550e-29, max E_trunc = 2.9104e-10
# chi: [4, 4]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-2202.2023157247895142, max S=0.0000028064212302, age=248, norm_err=7.0e-16
# Current memory usage 551.1MB, wall time: 0.4s
# Delta E = 7.2760e-12, Delta S = -1.5609e-06 (per sweep)
# max trunc_err = 1.4040e-22, max E_trunc = 5.8208e-11
# chi: [3, 3]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-2202.2023157247895142, max S=0.0000002470131945, age=368, norm_err=5.4e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 0.0000e+00, Delta S = -2.5594e-07 (per sweep)
# max trunc_err = 2.1404e-24, max E_trunc = 1.1642e-10
# chi: [2, 2]
# ...
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=50650.650650650656
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-50650.6506555862724781, max S=0.0000182407678728, age=128, norm_err=1.4e-26
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = nan, Delta S = 1.8241e-06 (per sweep)
# max trunc_err = 1.1871e-21, max E_trunc = 9.3132e-10
# chi: [2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-50650.6506555862724781, max S=0.0000026053514828, age=248, norm_err=1.4e-26
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 0.0000e+00, Delta S = -1.5635e-06 (per sweep)
# max trunc_err = 1.1885e-21, max E_trunc = -3.7253e-09
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-50650.6506555862724781, max S=0.0000000006197164, age=368, norm_err=3.1e-16
# Current memory usage 551.1MB, wall time: 0.1s
# Delta E = 0.0000e+00, Delta S = -2.6047e-07 (per sweep)
# max trunc_err = 8.2003e-29, max E_trunc = 0.0000e+00
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=50750.750750750754
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-50750.7507556756027043, max S=0.0000182407665679, age=128, norm_err=8.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = nan, Delta S = 1.8241e-06 (per sweep)
# max trunc_err = 1.1778e-21, max E_trunc = 1.8626e-09
# chi: [2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-50750.7507556742057204, max S=0.0000026053499780, age=248, norm_err=5.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 1.3970e-10, Delta S = -1.5635e-06 (per sweep)
# max trunc_err = 1.1795e-21, max E_trunc = 3.7253e-09
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-50750.7507556728087366, max S=0.0000000006173699, age=368, norm_err=8.0e-16
# Current memory usage 551.1MB, wall time: 0.1s
# Delta E = 1.3970e-10, Delta S = -2.6047e-07 (per sweep)
# max trunc_err = 1.4350e-27, max E_trunc = 1.6764e-08
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=50850.85085085085
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-50850.8508557660970837, max S=0.0000182407652706, age=128, norm_err=8.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = nan, Delta S = 1.8241e-06 (per sweep)
# max trunc_err = 1.1686e-21, max E_trunc = 9.3132e-10
# chi: [2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-50850.8508557653985918, max S=0.0000026053484823, age=248, norm_err=8.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 6.9849e-11, Delta S = -1.5635e-06 (per sweep)
# max trunc_err = 1.1686e-21, max E_trunc = 5.5879e-09
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-50850.8508557612076402, max S=0.0000000006150369, age=368, norm_err=5.0e-16
# Current memory usage 551.1MB, wall time: 0.1s
# Delta E = 4.1910e-10, Delta S = -2.6047e-07 (per sweep)
# max trunc_err = 1.0194e-27, max E_trunc = 1.1176e-08
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=50950.95095095095
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-50950.9509558577556163, max S=0.0000182407639811, age=128, norm_err=2.2e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = nan, Delta S = 1.8241e-06 (per sweep)
# max trunc_err = 1.1596e-21, max E_trunc = 0.0000e+00
# chi: [2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-50950.9509558589197695, max S=0.0000026053469954, age=248, norm_err=2.2e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -1.1642e-10, Delta S = -1.5635e-06 (per sweep)
# max trunc_err = 1.1598e-21, max E_trunc = 0.0000e+00
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-50950.9509558575227857, max S=0.0000000006127171, age=368, norm_err=2.2e-16
# Current memory usage 551.1MB, wall time: 0.1s
# Delta E = 1.3970e-10, Delta S = -2.6047e-07 (per sweep)
# max trunc_err = 6.5566e-29, max E_trunc = 1.8626e-09
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=51051.05105105106
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-51051.0510559465037659, max S=0.0000182407626990, age=128, norm_err=5.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = nan, Delta S = 1.8241e-06 (per sweep)
# max trunc_err = 1.1507e-21, max E_trunc = 1.8626e-09
# chi: [2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-51051.0510559456888586, max S=0.0000026053455172, age=248, norm_err=5.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 8.1491e-11, Delta S = -1.5635e-06 (per sweep)
# max trunc_err = 1.1502e-21, max E_trunc = 5.5879e-09
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-51051.0510559435933828, max S=0.0000000006104110, age=368, norm_err=5.0e-16
# Current memory usage 551.1MB, wall time: 0.1s
# Delta E = 2.0955e-10, Delta S = -2.6047e-07 (per sweep)
# max trunc_err = 1.3324e-28, max E_trunc = 1.8626e-09
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=51151.151151151156
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-51151.1511560418875888, max S=0.0000182407614245, age=128, norm_err=6.7e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = nan, Delta S = 1.8241e-06 (per sweep)
# max trunc_err = 1.1412e-21, max E_trunc = -2.7940e-09
# chi: [2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-51151.1511560452636331, max S=0.0000026053440480, age=248, norm_err=6.7e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = -3.3760e-10, Delta S = -1.5635e-06 (per sweep)
# max trunc_err = 1.1409e-21, max E_trunc = -1.8626e-09
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-51151.1511560408398509, max S=0.0000000006081177, age=368, norm_err=2.2e-16
# Current memory usage 551.1MB, wall time: 0.1s
# Delta E = 4.4238e-10, Delta S = -2.6047e-07 (per sweep)
# max trunc_err = 9.0154e-28, max E_trunc = 3.7253e-09
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=51251.251251251255
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-51251.2512561276089400, max S=0.0000182407601574, age=128, norm_err=8.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = nan, Delta S = 1.8241e-06 (per sweep)
# max trunc_err = 1.1326e-21, max E_trunc = 2.7940e-09
# chi: [2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 20
# energy=-51251.2512561264447868, max S=0.0000026053425869, age=248, norm_err=5.0e-16
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = 1.1642e-10, Delta S = -1.5635e-06 (per sweep)
# max trunc_err = 1.1329e-21, max E_trunc = 0.0000e+00
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate DensityMatrixMixer with final amplitude 1.5624999999999996e-07
# INFO    : Running sweep with optimization
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 30
# energy=-51251.2512561320327222, max S=0.0000000006058377, age=368, norm_err=5.0e-16
# Current memory usage 551.1MB, wall time: 0.1s
# Delta E = -5.5879e-10, Delta S = -2.6047e-07 (per sweep)
# max trunc_err = 1.2046e-27, max E_trunc = 3.7253e-09
# chi: [2, 2]
# ================================================================================
# INFO    : TwoSiteDMRGEngine finished after 30 sweeps, max chi=2
# INFO    : TFIChain: reading 'bc_MPS'='infinite'
# INFO    : TFIChain: reading 'L'=2
# INFO    : TFIChain: reading 'J'=1
# INFO    : TFIChain: reading 'g'=51351.35135135135
# INFO    : DMRG: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : start environment_sweep
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-10
# INFO    : DMRG: reading 'mixer'=True
# INFO    : activate DensityMatrixMixer with initial amplitude 1e-05
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=5.0000000000000005e-22
# INFO    : start environment_sweep
# INFO    : checkpoint after sweep 10
# energy=-51351.3513562199659646, max S=0.0000182407588976, age=128, norm_err=1.4e-26
# Current memory usage 551.1MB, wall time: 0.2s
# Delta E = nan, Delta S = 1.8241e-06 (per sweep)
# max trunc_err = 1.1234e-21, max E_trunc = 5.5879e-09
# chi: [2, 2]
# ================================================================================
# INFO    : Running sweep with optimization

# %%
plt.figure(figsize=(6, 6))
plt.plot(g_arr, Sz_arr)
plt.title("Infinite Sites")
plt.xlabel("g")
plt.ylabel("<x>")
plt.show()
